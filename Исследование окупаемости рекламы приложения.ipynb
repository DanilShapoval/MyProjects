# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Данные--для-анализа" data-toc-modified-id="Данные--для-анализа-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Данные  для анализа</a></span><ul class="toc-item"><li><span><a href="#Датасет-visits" data-toc-modified-id="Датасет-visits-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Датасет <code>visits</code></a></span></li><li><span><a href="#Датасет-orders" data-toc-modified-id="Датасет-orders-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Датасет <code>orders</code></a></span></li><li><span><a href="#Датасет-costs" data-toc-modified-id="Датасет-costs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Датасет <code>costs</code></a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Проведите-исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Пользовательские-профили.-Минимальная-и-максимальная-даты-привлечения-пользователей." data-toc-modified-id="Пользовательские-профили.-Минимальная-и-максимальная-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Пользовательские профили. Минимальная и максимальная даты привлечения пользователей.</a></span></li><li><span><a href="#Cтраны" data-toc-modified-id="Cтраны-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cтраны</a></span></li><li><span><a href="#Устройства" data-toc-modified-id="Устройства-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Устройства</a></span></li><li><span><a href="#Рекламные-источники-привлечения" data-toc-modified-id="Рекламные-источники-привлечения-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Рекламные источники привлечения</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы" data-toc-modified-id="Расходы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы</a></span><ul class="toc-item"><li><span><a href="#Траты-по-источникам" data-toc-modified-id="Траты-по-источникам-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Траты по источникам</a></span></li><li><span><a href="#Изменения-метрик-во-времени" data-toc-modified-id="Изменения-метрик-во-времени-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Изменения метрик во времени</a></span></li></ul></li><li><span><a href="#Cредняя-стоимость-привлечение-одного-пользователя" data-toc-modified-id="Cредняя-стоимость-привлечение-одного-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Cредняя стоимость привлечение одного пользователя</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс.

# %% [markdown]
# ## Данные  для анализа
# Данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
data = pd.read_csv('orders_info_short.csv')
data.to_csv('orders_info_short.csv', index=False)

# %%
visits, orders, costs = (pd.read_csv('visits_info_short.csv'),
                         pd.read_csv('orders_info_short.csv'),
                         pd.read_csv('costs_info_short.csv'))
display (visits.head(), orders.head(), costs.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# ### Датасет `visits`

# %% [markdown]
# **Рассмотрим датасет `visits`**

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Приведем названия столбцов к "змеиному регистру" и преобразуем данные начала и конца сессии в формат `datetime64`

# %%
visits.columns = visits.columns.str.lower()
(visits.rename
 (columns = {'user id' : 'user_id', 
             'session start' : 'session_start', 
             'session end' : 'session_end'}, 
  inplace = True))
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# Проверим на наличие явных дубликатов

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов нет

# %% [markdown]
# Проверим на наличие неявных дубликатов в столбцах `region`,`device`, `channel`

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявных дубликатов также нет в данном датафрейме.

# %% [markdown]
# ### Датасет `orders`

# %% [markdown]
# **Рассмотрим датасет `orders`**

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Приведем названия столбцов к "змеиному регистру" и преобразуем данные о дате и времени покупки в формат `datetime64`

# %%
orders.columns = orders.columns.str.lower()
(orders.rename
 (columns = {'user id' : 'user_id', 
             'event dt' : 'event_dt'}, 
  inplace = True))
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# Проверим на наличие явных дубликатов

# %%
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов нет

# %% [markdown]
# Неявных дубликатов в этом датафрейме быть не может.

# %% [markdown]
# ### Датасет `costs`

# %% [markdown]
# **Рассмотрим датасет `costs`**

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Приведем названия столбцов к "змеиному регистру" и преобразуем данные о проведении рекламной кампании в формат `date`

# %%
costs.columns = costs.columns.str.lower()

costs['dt'] = pd.to_datetime(costs['dt']).dt.date 

costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Проверим на наличие явных дубликатов

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов нет

# %% [markdown]
# Проверим на наличие неявных дубликатов в столбце `channel`

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявных дубликатов также нет в данном датафрейме.

# %% [markdown]
# Данные загружены и преобразованы в перемнные, приведены к необходимым форматам, проверены на наличие дубликатов (явных и неявных дубликатов нет)

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    profiles = (sessions.sort_values(by=['user_id', 'session_start'])
                .groupby('user_id')
                .agg({'session_start': 'first',
                      'channel': 'first',
                      'device': 'first',
                      'region': 'first',})
                .rename(columns={'session_start': 'first_ts'})
                .reset_index())

    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    
    new_users = (profiles.groupby(['dt', 'channel'])
                 .agg({'user_id': 'nunique'})
                 .rename(columns={'user_id': 'unique_users'})
                 .reset_index())
    
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    profiles = profiles.merge(ad_costs[['dt', 'channel', 'acquisition_cost']],
                              on=['dt', 'channel'],
                              how='left')
    
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(profiles,
                  sessions,
                  observation_date,
                  horizon_days,
                  dimensions=[],
                  ignore_horizon=False):

    dimensions = ['payer'] + dimensions
    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique')
        cohort_sizes = (df.groupby(dims)
                        .agg({'user_id': 'nunique'})
                        .rename(columns={'user_id': 'cohort_size'}))
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
   
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(profiles,
                   purchases,
                   observation_date,
                   horizon_days,
                   dimensions=[],
                   ignore_horizon=False):
    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    first_purchases = (purchases.sort_values(by=['user_id', 'event_dt'])
                       .groupby('user_id')
                       .agg({'event_dt': 'first'})
                       .reset_index())
    
    result_raw = result_raw.merge(first_purchases[['user_id', 'event_dt']], on='user_id', how='left')
    
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']
    
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique')
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (df.groupby(dims)
                        .agg({'user_id': 'nunique'})
                        .rename(columns={'user_id': 'cohort_size'}))
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
   
    if 'cohort' in dimensions: 
        dimensions = []
    
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(profiles,
            purchases,
            observation_date,
            horizon_days,
            dimensions=[],
            ignore_horizon=False):
    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    result_raw = result_raw.merge(purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left')
        
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']
    
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(index=dims, columns='lifetime', values='revenue', aggfunc='sum')
        result = result.fillna(0).cumsum(axis=1)        
        cohort_sizes = (df.groupby(dims)
                        .agg({'user_id': 'nunique'})
                        .rename(columns={'user_id': 'cohort_size'}))
        
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)        
        result = result.div(result['cohort_size'], axis=0)        
        result = result[['cohort_size'] + list(range(horizon_days))]        
        result['cohort_size'] = cohort_sizes

        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        
        cac = (cac.groupby(dims)
               .agg({'acquisition_cost': 'mean'})
               .rename(columns={'acquisition_cost': 'cac'}))
        
        roi = result.div(cac['cac'], axis=0)        
        roi = roi[~roi['cohort_size'].isin([np.inf])]        
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
       
        return result, roi
  
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days)
    
    if 'cohort' in dimensions:
        dimensions = []
    
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days)

    return (result_raw,
            result_grouped,
            result_in_time,
            roi_grouped,
            roi_in_time)

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    plt.figure(figsize=(15, 10))

    retention = retention.drop(columns=['cohort_size', 0])
    retention_history = retention_history.drop(columns=['cohort_size'])[[horizon - 1]]
    
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])
    
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(grid=True, ax=ax2)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    ax3 = plt.subplot(2, 2, 3)
    columns = [name
               for name in retention_history.index.names
               if name not in ['dt', 'payer']]
    
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания платящих пользователей на {}-й день'.format(horizon))

    ax4 = plt.subplot(2, 2, 4, sharey=ax3)    
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика удержания неплатящих пользователей на {}-й день'.format(horizon))
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    plt.figure(figsize=(15, 5))

    conversion = conversion.drop(columns=['cohort_size'])
    conversion_history = conversion_history.drop(columns=['cohort_size'])[[horizon - 1]]

    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [name for name in conversion_history.index.names if name not in ['dt']]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    plt.figure(figsize=(20, 10))

    ltv = ltv.drop(columns=['cohort_size'])
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    cac_history = roi_history[['cac']]

    roi = roi.drop(columns=['cohort_size', 'cac'])
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[[horizon - 1]]

    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    ax3 = plt.subplot(2, 3, 3, sharey=ax1) 
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ### Пользовательские профили. Минимальная и максимальная даты привлечения пользователей.

# %%
profiles = get_profiles(visits, orders, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
min_dt = profiles['dt'].min()
min_dt
# Out:
# datetime.date(2019, 5, 1)

# %%
max_dt = profiles['dt'].max()
max_dt
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# Даты соответствуют полученным вводным данным. Данные за весь анализируемый период присутствуют в датафрейме

# %% [markdown]
# ### Cтраны

# %%
regions = profiles.pivot_table(index = 'region', columns ='payer', values = 'user_id', aggfunc ='nunique')
regions.columns = ['non_payer', 'payer']
regions['users_total']= regions['non_payer']+regions['payer']
regions['share_%'] = (regions['payer']/regions['users_total'])*100
regions['total_share_%'] = (regions['payer']/(regions['payer'].sum()))*100
regions=regions.sort_values(by='users_total', ascending=False)
regions
# Out:
#                non_payer  payer  users_total   share_%  total_share_%
# region
# United States      93100   6902       100002  6.901862      77.716473
# UK                 16875    700        17575  3.982930       7.881995
# France             16787    663        17450  3.799427       7.465376
# Germany            14365    616        14981  4.111875       6.936156

# %% [markdown]
# Пользователи приходят из 4 стран: Франция, Германия, Великобритания и США. Большинство пользователей приходят из США. Доля платящих от общего количества пользователей в стране для всех стран менее 7%, однако в США она наибольшая, учитывая, что пользователей в США так же больше, количество платящих пользоватетлей в США больше, чем в других странах в 10 раз. Как результат, при рассчете доли платящих пользователей по странам от общего количества платящих пользователей, доля пользователей из США от общего количества платящих пользователей приближается к 78%, прочие страны делят оставшиеся 22% примерно поровну.

# %% [markdown]
# ### Устройства

# %%
devices = profiles.pivot_table(index = 'device', columns ='payer', values = 'user_id', aggfunc ='nunique')
devices.columns = ['non_payer', 'payer']
devices['users_total']= devices['non_payer']+devices['payer']
devices['share-%'] = (devices['payer']/devices['users_total'])*100
devices['total_share_%'] = (devices['payer']/(devices['payer'].sum()))*100
devices=devices.sort_values(by='users_total', ascending=False)
devices
# Out:
#          non_payer  payer  users_total   share-%  total_share_%
# device
# iPhone       51097   3382        54479  6.207897      38.081297
# Android      32982   2050        35032  5.851793      23.082986
# PC           28918   1537        30455  5.046790      17.306610
# Mac          28130   1912        30042  6.364423      21.529107

# %% [markdown]
# Пользователи используют 4 типа устройств: Android, Mac, PC и iPhone. Количество пользователей по типам устройств распределено относительно равномерно, выделяются только  пользователи iPhone, их примерно в полтора раза больше. Доля платящих от общего количества пользователей по типу устройств около 5-6%. При рассчете доли платящих пользователей по типу устройств от общего количества платящих пользователей, доля пользователей iPhone от общего количества платящих пользователей составляет около 38% за счет того, что пользователей iPhone больше, прочие типы устройств делят оставшиеся 62% относительно поровну.

# %% [markdown]
# ### Рекламные источники привлечения

# %%
channels = profiles.pivot_table(index = 'channel', columns ='payer', values = 'user_id', aggfunc ='nunique')
channels.columns = ['non_payer', 'payer']
channels['users_total']= channels['non_payer']+channels['payer']
channels['share_%'] = (channels['payer']/channels['users_total'])*100
channels['total_share_%'] =( channels['payer']/(channels['payer'].sum()))*100
channels=channels.sort_values(by='users_total', ascending=False)
channels
# Out:
#                     non_payer  payer  users_total    share_%  total_share_%
# channel
# organic                 55279   1160        56439   2.055316      13.061592
# FaceBoom                25587   3557        29144  12.204914      40.051796
# TipTop                  17683   1878        19561   9.600736      21.146267
# OppleCreativeMedia       8372    233         8605   2.707728       2.623578
# LeapBob                  8291    262         8553   3.063253       2.950118
# WahooNetBanner           8100    453         8553   5.296387       5.100777
# RocketSuperAds           4096    352         4448   7.913669       3.963518
# MediaTornado             4208    156         4364   3.574702       1.756559
# YRabbit                  4147    165         4312   3.826531       1.857899
# AdNonSense               3440    440         3880  11.340206       4.954397
# lambdaMediaAds           1924    225         2149  10.469986       2.533498

# %% [markdown]
# Пользователи приходят из 11 источников привлечения. Наибольшее количество пользователей компании приносят 3 источника, причем один из них - бесплатный - пользователи, пришедшие органически, оставшиеся 2 источника - FaceBoom	и TipTop. Так же эти 3 источника приносят наибольшее клоичество платящих пользователей, причем, органические попали втоп лишь благодаря большому количеству привлеченных пользователей, поскольку доля платящих по отношению к общему количеству пользователей из источника не высока. Доля платящих по отношению к общему количеству пользователей для каждого канала привлечения, не отображает эффективность рекламы, поскольку, она может быть высокой для канала, принесшего небольшое количество пользователей в результате чего, вне зависимости от размера доли, количество привлеченных платящих пользоватетлей будет невысоко. Доля же платящих по отношению к общему количеству платящих пользователей, выделяет 3 основных источника привлечения платежеспособных клиентов, если не брать органически привлеченных, то 2. Возможно стоит сделать в маркетинговой стратегии больший упор на FaceBoom	и TipTop, поскольку, суммарно, они приносят 61% платящих пользователей.

# %% [markdown]
# ## Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# ### Расходы

# %%
print('Cумма расходов на маркетинг составила ', costs['costs'].sum().round(1), 'неизвестных денежных единиц')
# Out:
# Cумма расходов на маркетинг составила  105497.3 неизвестных денежных единиц

# %% [markdown]
# #### Траты по источникам

# %%
costs_per_channel=(costs.pivot_table(index = 'channel', values = 'costs', aggfunc ='sum')
                   .sort_values(by='costs', ascending=False))
costs_per_channel['share'] = costs_per_channel['costs']/(costs_per_channel['costs'].sum())
costs_per_channel
# Out:
#                        costs     share
# channel
# TipTop              54751.30  0.518983
# FaceBoom            32445.60  0.307549
# WahooNetBanner       5151.00  0.048826
# AdNonSense           3911.25  0.037074
# OppleCreativeMedia   2151.25  0.020392
# RocketSuperAds       1833.00  0.017375
# LeapBob              1797.60  0.017039
# lambdaMediaAds       1557.60  0.014764
# MediaTornado          954.48  0.009047
# YRabbit               944.22  0.008950

# %% [markdown]
# Учитывая то, что TipTop предоставляет только 21% платящих пользователей от их общего количества, траты на него в 51% от бощего рекламного бюджета выглядят крайне сомнительно, посмотрим, к чему это приведет. В остальном, 82% общего рекламного бюджета съели TipTop и FaceBoom, оставльные 9 источников привлечения поделили между собой оставшиеся 18% бюджета. Надеюсь сумма не в рублях, а то на них и пирожков сотрудникам не купить.

# %% [markdown]
# #### Изменения метрик во времени

# %%
costs_in_time=costs.pivot_table(index = 'channel',columns ='dt', values = 'costs')
costs_in_time.T.plot( grid=True,figsize=(15, 10))
plt.ylabel('Расходы на кампанию')
plt.xlabel('Дата')
plt.title('Динамика затрат на рекламу по источникам привлечения')
plt.show()

# %% [markdown]
# Получился довольно шумный график, воспользуемся плавающей суммой, чтобы уменьшить шумы

# %%
costs_in_time.T.rolling(7).sum().plot( grid=True,figsize=(15, 10))
plt.ylabel('Расходы на кампанию')
plt.xlabel('Дата')
plt.title('Динамика затрат на рекламу по источникам привлечения')
plt.show()

# %% [markdown]
# Пока виден только значительный рост затрат на рекламму в TipTop и FaceBoom, причем, если рост затрат на FaceBoom заметен, но не чрезмерен, то в рекламу на TipTop вливались какие-то уж совсем невероятные деньги (или чем все-таки платили? Чупа-Чупсами?)

# %% [markdown]
# Взглянем теперь поближе на более обделенные компании.

# %%
costs_in_time.query('channel !="TipTop" and channel !="FaceBoom"').T.rolling(30).sum().plot( grid=True,figsize=(15, 10))
plt.ylabel('Расходы на кампанию')
plt.xlabel('Дата')
plt.title('Динамика затрат на рекламу по источникам привлечения')
plt.show()

# %% [markdown]
# Источники привлечения с менее раздутым финансированием в течении наблюдаемого периода финансировались более равномерно, здесь выделяется AdNonSense	финансирование которго было на уровне лидеров по бюджетам, но упало уже к концу первого месяца рекламной компании, похоже, что отделу маркетинга стало очевидно, что дальнейшее финансирование данного источника на том же уровне принесет убытки. WahooNetBanner в отличие от AdNonSense стал получать куда большее финансирование в течении наблюдаемого периода. Создается ощущение, что деньги с маркетинговой кампании на  AdNonSense передали на кампанию на WahooNetBanner. Также, можно с уверенностью сказать, что первый месяц рекламной кампании выявил приоритетные источники, в результате чего, финансированиебыло пересмотрено, что объясняет резкие скачки графиков в первый месяц.

# %% [markdown]
#  Кроме того, стоит отметить, что в течении месяца, финансирование рекламных кампаний было неравномерно, в начале месяца часто наблюдается повышение сумм, а где-то в средине месяца - снижение сумм на рекламу. Также заметны скачки в июле и октябре, где значительно увеличивалось финансирование, возможно это связано с началом каникул и возможностью привлечь в Procrastinate Pro+ больше пользователей.

# %% [markdown]
# ### Cредняя стоимость привлечение одного пользователя

# %%
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
(print('Средняя стомость привлечения на одного пользователя для всего проекта составлят:'
       , round(profiles['acquisition_cost'].mean(),2), 'неизвестных денежных единиц'))
# Out:
# Средняя стомость привлечения на одного пользователя для всего проекта составлят: 0.7 неизвестных денежных единиц

# %%
profiles.pivot_table(
    index='dt',  values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС для всего проекта')
plt.show()

# %% [markdown]
# При рассмотрении общей картины проекта, видно что с течением времени стоимость привлечения одного клиента постепенно росла.

# %%
profiles.pivot_table(
    index='channel', values='acquisition_cost', aggfunc='mean'
).sort_values(by='acquisition_cost', ascending = False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Стоимость привлечения «органических» пользователей во всех когортах равна нулю, потому что они перешли на сайт самостоятельно, а не благодаря рекламе.
#
# Привлечение одного пользователя из TipTop обошлось компании в среднем в 2.8 условных едениц, что значительно превышает средний показатель по всему проекту. Также по графику динамики изсенения САС видно, стоимость привлечения одного клиента неумолимо росла.
#
# Также выше общесреднего САС у FaceBoom, AdNonSense и lambdaMediaAds, но в динамике их САС относительно стабилен. Также динамика САС стабильна и у других источников привлечения.

# %% [markdown]
# ## Окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Для исследования окупаемости рекламной кампании, данные по органическим пользователям нас мало интересуют. Исключим их из датафрейма `profiles`

# %%
profiles_adv= profiles.query('channel !="organic"')

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles_adv, orders, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# - Реклама не окупается. ROI в конце второй недели — чуть выше 80%.
# - Динамика стоимости привлечения пользователей (CAC) равномерно растет в течение всего рассматриваемого периода. Это значит, средняя стоимость превлечения одного пользователя росла.
# - Общая динамика удержания платящих пользователей на 14 день жизни относительна стабильна.
# - Динамика окупаемости (ROI) пользователей на 14-й день жизни со временем снижается, зеркально отражая рост САС.
#
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству пользователя.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = (get_ltv(profiles_adv, orders, observation_date, horizon_days, 
                                                                       dimensions=dimensions))

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Вот что говорят графики с разбивкой по утсройствам:
# - Реклама на РС начинает окупаться на 11 день жизни, на остальных устройствах реклама не окупается.
# - Стоимость привлечения на всех устройствах равномерно растет, однако н РС рост минимален, что может объяснить то, что ROI на РС на 11 день показывает окупаемость.
# - LTV всё так подвержен сезонности, но стабилен.
# - Затраты на привлечение пользователей Iphone и Мас максимальные, а окупаемость минимальная.
# - Лучше всего окупается РС.

# %% [markdown]
# **Конверсия с разбивкой по устройствам**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_adv, orders, observation_date, horizon_days, dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# Судя по графикам, пользователи iPhone и Мас конвертируются очень хорошо, причём постоянно. Видимо, дело в удержании.

# %% [markdown]
# **Удержание с разбивкой по устройствам**

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_adv, visits, observation_date, horizon_days, dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# Удержание пользователей к 14 дню жизни стабильно падает на всех устройствах. Заметных лидеров в удержании пользователей не наблюдается.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = (get_ltv(profiles_adv, orders, observation_date, horizon_days, 
                                                                       dimensions=dimensions))

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Вот что говорят графики с разбивкой по странам:
#
# - На 5 день жизни реклама во всех странах кроме USA начинает окупаться.
# - Динамика стоимости привлечения пользователей в USA кардинально отличается от других стран, там она значительно выше, а динамика окупаемости в свою очередь намного ниже, чем в других странах.

# %% [markdown]
# **Конверсия с разбивкой по странам**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_adv, orders, observation_date, horizon_days, dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=14)

# %% [markdown]
# Судя по графикам, пользователи из США конвертируются очень хорошо, причём постоянно. Видимо, дело в удержании.

# %% [markdown]
# **Удержание с разбивкой по странам**

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_adv, visits, observation_date, horizon_days, dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# Действительно, пользователи из США стабильно плохо удерживаются. В течение первой недели жизни их удержание намного ниже, чем в других странах. Однако, на второй неделе жизни резкая разница в удержании пользователей по странм сокращается.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = (get_ltv(profiles_adv, orders, observation_date, horizon_days, 
                                                                       dimensions=dimensions))

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=30)

# %% [markdown]
# Вот что говорят графики с разбивкой по каналам привлечения:
#
# - В течение первых 5-ти дней реклама оккупается на всех каналах привлечения, кроме TipTop, FaceBoom и AdNonSense, на этих каналах привлечения реклама не окупилась вовсе за 14 дней жизни.
# - Динамика стоимости привлечения пользователей на TipTop кардинально отличается от каналов привлечения, там она значительно выше.
# - Динамика окупаемости на TipTop и FaceBoom на 14 день жизни в течение всего рассматриваемого периода ниже уровня окупаемости.
# - Лучше всех окпаются пользователи, пришедшие с YRabbit.

# %% [markdown]
# **Конверсия с разбивкой по каналам привлечения**

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_adv, orders, observation_date, horizon_days, dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days, window=30)

# %% [markdown]
# Судя по графикам, пользователи из FaceBoom и AdNonSense конвертируются лучше остальных, причём постоянно. Видимо, дело в удержании.

# %% [markdown]
# **Удержание с разбивкой по каналам привлечения**

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_adv, visits, observation_date, horizon_days, dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Действительно, пользователи из FaceBoom и AdNonSense стабильно плохо удерживаются. Для платящих пользователей из FaceBoom и AdNonSense удержание 14-го дня значительно ниже, чем на остальных устройствах и примерно на равно 0.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# **Окупается ли реклама в целом?**

# %% [markdown]
# Исходя из графика общего ROI, рекламная компания не окупается (кривая не пересекает черту окупаемости)

# %% [markdown]
# **Какие устройства, страны и каналы могут снижать окупаемость рекламы?**

# %% [markdown]
# Исходя из анализа окупаемости рекламы с разбивкой по устройствам, странам и каналам, можно сделать предварительные выводы о том, что на снижение окупемости может влиять совокупность нескольких факторов, а именно:
# - устройства - затраты на привлечение пользователей Iphone и Мас максимальные, а окупаемость минимальная;
# - страна - в США ROI не доходит до черты окупаемости при постоянно растущей стоимости привлечения пользователей;
# - каналы привлечения - заметен приоритет, отданный в финансировании рекламных компаний на наиболее популярных платформах (если в этой паралельной вселенной аналоги таких родных соцсетей так же популярны)
#
# Сильнее всего выделяется сильно выросшее со временем финансирование рекламной компании на TipTop, это и будет наш первый подозреваемый.

# %% [markdown]
# **Чем могут быть вызваны проблемы окупаемости?**

# %% [markdown]
# Как было отмечено ранее, скорей всего, проблемы с окупаемостью связаны с тем, что ставка в рекламной компании была сделана на популярные платформы с большим охватом аудитории, но зубастыми расценками, кроме того, нельзя не отметить, что возможно, в погоне за пользователями из США на Iphone и Мас, акцент рекламы так же был смещен не в ту сторону.

# %% [markdown]
# **Опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.**

# %% [markdown]
# В качестве промежуточного вывода, можно предложить рекламному отделу отказаться от вливания основной части бюджета в соцсети и изучить возможности прочих имеющихся платформ. Возможно, в погоне за количеством привлеченных пользователей они упустили менее затратный и более эффективный источник привлечения пользователей более перспективных в плане конвертации в плательщиков.

# %% [markdown]
# ## Выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# Настала пора делать окончательные выводы. Пора проверить нашу самую очевидную гипотезу: **ставка в рекламной компании была сделана на популярные платформы с большим охватом аудитории, но зубастыми расценками и повышение их финансирования приносило только убытки, даже учитывая то, что они принесли наибольшее количество пользователей**

# %% [markdown]
# Исключим из датафрейма пользователей привлеченных из TipTop и взглянем на общую окупаемость.

# %%
profiles_adv_exp=profiles_adv.query('channel !="TipTop"')

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles_adv_exp, orders, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Наша рекламная кампания окупилась бы на 9 день, без финансирования TipTop, а что если и FaceBoom, так же повлиял на общую окупаемость? Проверим.

# %%
profiles_adv_exp=profiles_adv.query('channel !="TipTop"and channel !="FaceBoom"')

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles_adv_exp, orders, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Похоже мы нашли наш источник проблем, осталось проверить как исключение данных источников повлияло на динамики метрик по устройствам и странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = (get_ltv(profiles_adv_exp, orders, observation_date, horizon_days, 
                                                                       dimensions=dimensions))

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = (get_ltv(profiles_adv_exp, orders, observation_date, horizon_days, 
                                                                       dimensions=dimensions))

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Ожидаемо, динамики пришли в норму. Окупаются теперь и США и Iphone и Мас, причем довольно стабильно.

# %% [markdown]
# В качестве окончательных рекомендаций можно предложить минимизировать расходы на рекламу в  TipTop и FaceBoom, не стоит избавляться от платформ полностью, они охватывают часть рынка и помогают товару держаться на слуху, однако, строить всю компанию на рекламе в них - очевидно не эффективно. Кроме того, стоит пранализировать имеющиесяисточники привлечения клиентов, возможно среди них имеются золотые жилы.

# %% [markdown]
# Yrabbit и RocketSuperAds действительно являются наиболее перспектиными каналами, поскольку у них наибольшее удержание, с этим уже можно работать. Стоит попробовать немного повысить вливание средств в рекламу данных компаний и посмотреть к чему это приведет, если динамика стоимости привлечения не вырастет, а удержание останется на том же урорвне, при большем привлечении данные источники вполне могут принести немалую прибыль.
