# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названия-столбцов" data-toc-modified-id="Замена-названия-столбцов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Замена названия столбцов</a></span></li><li><span><a href="#Столбец-name" data-toc-modified-id="Столбец-name-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Столбец <code>name</code></a></span></li><li><span><a href="#Cтолбец-year_of_release" data-toc-modified-id="Cтолбец-year_of_release-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Cтолбец <code>year_of_release</code></a></span></li><li><span><a href="#Cтолбец-genre" data-toc-modified-id="Cтолбец-genre-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Cтолбец <code>genre</code></a></span></li><li><span><a href="#Cтолбец-critic_score" data-toc-modified-id="Cтолбец-critic_score-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Cтолбец <code>critic_score</code></a></span></li><li><span><a href="#Cтолбец--user_score" data-toc-modified-id="Cтолбец--user_score-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Cтолбец  <code>user_score</code></a></span></li><li><span><a href="#Cтолбец--rating" data-toc-modified-id="Cтолбец--rating-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Cтолбец  <code>rating</code></a></span></li><li><span><a href="#Cуммарные-продажи-во-всех-регионах" data-toc-modified-id="Cуммарные-продажи-во-всех-регионах-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Cуммарные продажи во всех регионах</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Игры-выпущенное-в-разные-годы" data-toc-modified-id="Игры-выпущенное-в-разные-годы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Игры выпущенное в разные годы</a></span></li><li><span><a href="#Анализ-по-платформам" data-toc-modified-id="Анализ-по-платформам-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Анализ по платформам</a></span><ul class="toc-item"><li><span><a href="#Период-жизни-платформ" data-toc-modified-id="Период-жизни-платформ-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Период жизни платформ</a></span></li><li><span><a href="#Популярные-платформы" data-toc-modified-id="Популярные-платформы-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Популярные платформы</a></span></li></ul></li><li><span><a href="#Актуальный-период" data-toc-modified-id="Актуальный-период-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Актуальный период</a></span></li><li><span><a href="#Определение-потенциально-прибыльных-платформ" data-toc-modified-id="Определение-потенциально-прибыльных-платформ-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Определение потенциально прибыльных платформ</a></span></li><li><span><a href="#Распределение-продаж-игр-по-платформам" data-toc-modified-id="Распределение-продаж-игр-по-платформам-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Распределение продаж игр по платформам</a></span></li><li><span><a href="#Зависимость-продаж-по-платформе-от-отзывов-пользователей-и-критиков" data-toc-modified-id="Зависимость-продаж-по-платформе-от-отзывов-пользователей-и-критиков-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Зависимость продаж по платформе от отзывов пользователей и критиков</a></span><ul class="toc-item"><li><span><a href="#По-платформе-PS3" data-toc-modified-id="По-платформе-PS3-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>По платформе PS3</a></span></li><li><span><a href="#По-всем-платформам" data-toc-modified-id="По-всем-платформам-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>По всем платформам</a></span></li><li><span><a href="#По-платформе-X360" data-toc-modified-id="По-платформе-X360-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>По платформе X360</a></span></li><li><span><a href="#По-PC" data-toc-modified-id="По-PC-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>По PC</a></span></li></ul></li><li><span><a href="#Общее-распределение-игр-по-жанрам" data-toc-modified-id="Общее-распределение-игр-по-жанрам-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Общее распределение игр по жанрам</a></span></li></ul></li><li><span><a href="#Портерет-пользователя-каждого-региона" data-toc-modified-id="Портерет-пользователя-каждого-региона-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Портерет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5)" data-toc-modified-id="Самые-популярные-платформы-(топ-5)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5)</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)" data-toc-modified-id="Самые-популярные-жанры-(топ-5)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5)</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в отдельном регионе</a></span></li><li><span><a href="#Общий-портрет-пользователя-каждого-региона" data-toc-modified-id="Общий-портрет-пользователя-каждого-региона-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Общий портрет пользователя каждого региона</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1-(Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые)" data-toc-modified-id="Гипотеза-1-(Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Гипотеза 1 (Средние пользовательские рейтинги платформ Xbox One и PC одинаковые)</a></span></li><li><span><a href="#Гипотеза-1-(Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные)" data-toc-modified-id="Гипотеза-1-(Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Гипотеза 1 (Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные)</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект №1

# %% [markdown]
# Описание проекта
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %%
import pandas as pd

# %%
games = pd.read_csv('games.csv')
display(games.head(10))
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Представленный для анализа датафрейм состоит из 16715 строк и 11 столбцов. В нем содержатся данные об играх, жанрах, платформах, их году выпуска, продажах по регионам и рейтингах.
# Данные представлены двумя типами: строковыми и вещественными числами. В данных присутсвуют пропуски, в названиях столбцов присутсвуют заглавные буквы. Рассмотрим датафрейм детально

# %% [markdown]
# ## Подготовка данных

# %%
games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В датафрейме отсутствуют полные дубликаты.

# %% [markdown]
# Поищем дубликаты по комбинации имя-консоль-год.

# %%
games.duplicated(['Name', 'Platform', 'Year_of_Release']).sum()
# Out:
# 2

# %%
games[games.duplicated(['Name', 'Platform', 'Year_of_Release'])]
# Out:
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 14244            NaN      GEN           1993.0     NaN       0.0      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports       0.0      0.01
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 14244      0.03          0.0           NaN        NaN    NaN
# 16230      0.00          0.0          83.0        5.5      E

# %% [markdown]
#  Обнаружено два дубликата. Со строками, в которых присутсвуют "NaN" в столбце 'Name' разберемся позднее.
# Строки со значением "Madden NFL 13"	 в столбце 'Name' на платформе "PS3" заменим одной строкой, просуммировав значения продаж по регионам. Возможно, данный дубликат появился в результате того, что игру в какой-то момент обновляли, благодаря чему появилась новая строка в логах статистики сайта.

# %%
games.query('Name == "Madden NFL 13" and Platform == "PS3"')
# Out:
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 604         0.0         0.23          83.0        5.5      E
# 16230       0.0         0.00          83.0        5.5      E

# %%
new_row = ({'Name':'Madden NFL 13', 'Platform':'PS3', 'Year_of_Release':2012.0, 'Genre':'Sports', 'NA_sales': 2.11, 
           'EU_sales': 0.23, 'JP_sales': 0.0, 'Other_sales': 0.23, 'Critic_Score': 83.0, 'User_Score': 5.5, 'Rating': 'E'})
games = games.drop(index=[604, 16230])
games = games.append(new_row, ignore_index=True).reset_index(drop=True)
games.query('Name == "Madden NFL 13" and Platform == "PS3"')
# Out:
# C:\Users\Avalon\AppData\Local\Temp\ipykernel_8988\3553296445.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   games = games.append(new_row, ignore_index=True).reset_index(drop=True)
#                 Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 16713  Madden NFL 13      PS3           2012.0  Sports      2.11      0.23
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 16713       0.0         0.23          83.0        5.5      E

# %% [markdown]
# ### Замена названия столбцов

# %% [markdown]
# В датафрейме присутствуют назавания столбцов, содержащие символы в верхем регистре. Приведем все к нижнему регистру, методом `str.lower()`

# %%
games.columns=games.columns.str.lower()
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16714 entries, 0 to 16713
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16712 non-null  object
#  1   platform         16714 non-null  object
#  2   year_of_release  16445 non-null  float64
#  3   genre            16712 non-null  object
#  4   na_sales         16714 non-null  float64
#  5   eu_sales         16714 non-null  float64
#  6   jp_sales         16714 non-null  float64
#  7   other_sales      16714 non-null  float64
#  8   critic_score     8136 non-null   float64
#  9   user_score       10013 non-null  object
#  10  rating           9948 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Столбец `name`

# %%
games['name'].nunique()
# Out:
# 11559

# %%
games[games['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 658    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14243  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 658           0.08           NaN        NaN    NaN
# 14243         0.00           NaN        NaN    NaN

# %% [markdown]
# Пропуски присутствуют в 2х строках столбца `name`. Так как для будущего анализа название игры нам не понадобится, а будут необходимы данные о платформах, годах выпуска и количестве продаж, то оставим эти строки.

# %%
games['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1330
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %% [markdown]
# ### Cтолбец `year_of_release`

# %% [markdown]
# Необходимо привести данные, обозначающие год выпуска к целочисленным значениям.

# %%
games['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# В данных присутствуют `nan` значения, постараемся от них избавиться.

# %%
games[games['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 608                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16371  PDC World Championship Darts 2008      PSP              NaN
# 16403                      Freaky Flyers       GC              NaN
# 16446                          Inversion       PC              NaN
# 16456        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16520                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
print('Доля игр с пропущенным значением года выпуска:', round(games['year_of_release'].isna().sum()/len(games), 3))
# Out:
# Доля игр с пропущенным значением года выпуска: 0.016

# %% [markdown]
# Если бы исследование проводилось для существующей компании, в этот момент мы бы обратились к ее представителям для уточнения данных. Также можно воспользоваться интернет-ресурсом и посмотреть год выпуска для этих игр для каждой платформы вручную, однако это трудоемко. Примем решение избавиться от 1,6% данных датафрейма, поскольку невозможно провести анализ по годам по этим данным.

# %%
games =games.dropna(subset=['year_of_release']).reset_index(drop=True)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16445 entries, 0 to 16444
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16445 non-null  object
#  2   year_of_release  16445 non-null  float64
#  3   genre            16443 non-null  object
#  4   na_sales         16445 non-null  float64
#  5   eu_sales         16445 non-null  float64
#  6   jp_sales         16445 non-null  float64
#  7   other_sales      16445 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games['year_of_release'] = games['year_of_release'].astype('int')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16445 entries, 0 to 16444
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16445 non-null  object
#  2   year_of_release  16445 non-null  int32
#  3   genre            16443 non-null  object
#  4   na_sales         16445 non-null  float64
#  5   eu_sales         16445 non-null  float64
#  6   jp_sales         16445 non-null  float64
#  7   other_sales      16445 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(5), int32(1), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# Оставшиеся значения в столбце `year_of_release` преобразовали в целочисленные значения.

# %% [markdown]
# ### Cтолбец `genre`

# %%
games[games['genre'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 651    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14021  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 651           0.08           NaN        NaN    NaN
# 14021         0.00           NaN        NaN    NaN

# %% [markdown]
# Отсутствующие значения в столбце `genre` соответствуют пропускам в столбце `name`. Оставим пока строки без изменений, поскольку определить жанр мы не можем, однако количественные показатели в данных строках заполнены.

# %% [markdown]
# Удалим эти строки, заодно, избавимся от дубликатов по комбинации имя-консоль-год.

# %%
games= games.dropna(subset=['name']).reset_index(drop=True)
games['genre'].isna().sum()
# Out:
# 0

# %% [markdown]
# Столбцы `na_sales`, `eu_sales`, `jp_sales`, `other_sales`, представляющие данные о количестве продаж в регионах, заполнены без пропусков.

# %% [markdown]
# ### Cтолбец `critic_score`

# %%
games[games['critic_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16438               LMA Manager 2007     X360             2006        Sports
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16440               Spirits & Spells      GBA             2003      Platform
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
print('Доля игр с пропущенным значением оценки критиков:', round(games['critic_score'].isna().sum()/len(games), 3))
# Out:
# Доля игр с пропущенным значением оценки критиков: 0.515

# %% [markdown]
# Поскольку доля игр с пропущенными значениями в столбце `critic_score` составляет 51,5%, то избавиться от них будет опрометчиво, а заполнять средним или медианным значением некорректно, поскольку каждая игра самостоятельна и не зависит от других игр, так же как и одна и таже игра на разных платформах, поскольку оценка критиков может включать в себя, как оценку сюжета игра , так и оценку технического исполнения (баги, удобство интерфейса и т.п.).

# %% [markdown]
# ### Cтолбец  `user_score`

# %%
games[games['user_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16438               LMA Manager 2007     X360             2006        Sports
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16440               Spirits & Spells      GBA             2003      Platform
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7', 5.5],
#       dtype=object)

# %%
games[games['user_score'] == 'tbd']
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     Zumba Fitness      Wii             2010      Sports
# 300    Namco Museum: 50th Anniversary      PS2             2005        Misc
# 516                   Zumba Fitness 2      Wii             2011      Sports
# 638                      uDraw Studio      Wii             2010        Misc
# 708                   Just Dance Kids      Wii             2010        Misc
# ...                               ...      ...              ...         ...
# 16422                 Planet Monsters      GBA             2001      Action
# 16424                Bust-A-Move 3000       GC             2003      Puzzle
# 16425                Mega Brain Boost       DS             2008      Puzzle
# 16431                        Plushees       DS             2008  Simulation
# 16433   Men in Black II: Alien Escape       GC             2003     Shooter
#
# ...

# %% [markdown]
# Переведем строковые значения в вещественные, значение `tbd` пока проигнорируем.

# %%
games['user_score']=pd.to_numeric(games['user_score'], errors='ignore')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16443 entries, 0 to 16442
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int32
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       9838 non-null   object
#  10  rating           9767 non-null   object
# dtypes: float64(5), int32(1), object(5)
# memory usage: 1.3+ MB

# %%
games[games['user_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16438               LMA Manager 2007     X360             2006        Sports
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16440               Spirits & Spells      GBA             2003      Platform
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
print('Доля игр с пропущенным значением оценки пользователей:', round(games['user_score'].isna().sum()/len(games), 3))
# Out:
# Доля игр с пропущенным значением оценки пользователей: 0.402

# %%
print('Доля игр с пропущенным значением оценки пользователей:', round((games['user_score']=='tbd').sum()/len(games), 3))
# Out:
# Доля игр с пропущенным значением оценки пользователей: 0.144

# %% [markdown]
# Поскольку доля игр с пропущенными значениями в столбце `user_score` составляет 40.2%, то избавиться от них будет опрометчиво, а заполнять средним или медианным значением некорректно, поскольку каждая игра самостоятельна и не зависит от других игр, так же как и одна и таже игра на разных платформах, поскольку оценка пользователей может включать в себя, как оценку сюжета игра , так и оценку технического исполнения (баги, удобство интерфейса и т.п.).
#
# Кроме того, в данных присутсвует значение `tbd`, которое означает `To Be Determined`, то есть "Будет определено". Данные значения, также нельзя заполнить ни медианой, ни средним, ни нулем.
#
# Фактически пропущенных значений в столбце `user_score` около 55%.

# %% [markdown]
# ### Cтолбец  `rating`

# %%
games[games['rating'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16438               LMA Manager 2007     X360             2006        Sports
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16440               Spirits & Spells      GBA             2003      Platform
# 16441            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
games['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
print('Доля игр с пропущенным значением возрастного рейтинга:', round(games['rating'].isna().sum()/len(games), 3))
# Out:
# Доля игр с пропущенным значением возрастного рейтинга: 0.406

# %% [markdown]
# Доля игр с пропущенными значениями в столбце `rating` составляет 40.6%. Так как данные в этом столбце являются категориальными и определяются отдельно по каждой игре, заполнить их самостоятельно не представляется возможным, а при их удалении потеряем большое количество данных. Оставим столбец без изменений.

# %% [markdown]
# Скорее всего, игры, вышедшие после 90х годов, могли выходить в цифровых магазинах или в странах и у издателей, не требовавших  определения рейтинга, соответственно разработчик сертификацию игры не проводил. А до 90х сертификации не существовало.

# %% [markdown]
# Также не все игры получают оценки, а некоторые могли просто не успеть собрать нужное количество оценок.

# %% [markdown]
# ### Cуммарные продажи во всех регионах

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
display (games)
# Out:
#                            name platform  year_of_release         genre  \
# 0                    Wii Sports      Wii             2006        Sports
# 1             Super Mario Bros.      NES             1985      Platform
# 2                Mario Kart Wii      Wii             2008        Racing
# 3             Wii Sports Resort      Wii             2009        Sports
# 4      Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                         ...      ...              ...           ...
# 16438          LMA Manager 2007     X360             2006        Sports
# 16439   Haitaka no Psychedelica      PSV             2016     Adventure
# 16440          Spirits & Spells      GBA             2003      Platform
# 16441       Winning Post 8 2016      PSV             2016    Simulation
# 16442             Madden NFL 13      PS3             2012        Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Игры выпущенное в разные годы

# %%
games.groupby('year_of_release')['name'].nunique()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      40
# 1992      41
# 1993      59
# 1994     117
# 1995     215
# 1996     258
# 1997     282
# 1998     364
# 1999     326
# 2000     325
# 2001     428
# 2002     631
# 2003     546
# 2004     550
# 2005     657
# 2006     773
# 2007     884
# 2008    1039
# 2009    1001
# 2010     900
# 2011     779
# 2012     446
# 2013     335
# 2014     319
# 2015     362
# 2016     297
# Name: name, dtype: int64

# %%
anual_release = games.pivot_table(index = 'year_of_release', values = 'name', aggfunc = 'nunique')
anual_release = anual_release.reset_index()
(anual_release.plot(x='year_of_release', kind='bar', figsize = (10,10), grid=True, title='Количество выпускаемых игр по годам',
                   xlabel = 'год выпуска игр', ylabel='количество выпущенных игр'));

# %%
anual_release['name'].describe()
# Out:
# count      37.000000
# mean      329.594595
# std       319.135504
# min         9.000000
# 25%        36.000000
# 50%       297.000000
# 75%       546.000000
# max      1039.000000
# Name: name, dtype: float64

# %%
print('Доля игр с пропущенным значением оценки пользователей:', round(anual_release.query('name < 200')['name'].sum()/anual_release['name'].sum(),3))
# Out:
# Доля игр с пропущенным значением оценки пользователей: 0.039

# %% [markdown]
# На диаграмме заметен резкий скачок количества выпущенных игр в районе 94-95 годов. После этого периода количесвто выпускаемых игр в год сотавляло не менее 200 игр. Был заметный скачок в 2007-2008 годах - пириоод бурного развития игровой индустрии. Резкий спад количества выпускаемых игр в год связан с мировым экономическим кризисом 2009 года и рядом необдуманных заявлений крупных IT-гигантов относительно новых и не до конца проработанных технологий. Все это привело к спаду интереса к игровой индустрии, банкротству многих студий и оттоку спроса в пользу индустрии мобильных игр.

# %% [markdown]
# Для дальнейшего анализа будем рассматривать игры, выпущенные с 1995 года, когда игровая индустрия начала активно развиваться, выдавая свыше 200 наименований в год.

# %% [markdown]
# ### Анализ по платформам

# %%
anual_platform = games.pivot_table(index = 'platform',  values = 'total_sales', aggfunc = 'sum')
anual_platform.sort_values(by='total_sales', ascending=False)
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# Wii            891.18
# DS             802.78
# PS             727.58
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81
# PC             255.76
# GB             254.43
# XB             251.57
# NES            251.05
# N64            218.01
# SNES           200.04
# GC             196.73
# XOne           159.32
# 2600            86.48
# WiiU            82.19
# PSV             53.81
# SAT             33.59
# GEN             28.35
# DC              15.95
# SCD              1.86
# NG               1.44
# WS               1.42
# TG16             0.16
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %%
anual_release = games.pivot_table(index = 'year_of_release', values = 'name', aggfunc = 'nunique')

# %%
anual_release
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               40
# 1992               41
# 1993               59
# 1994              117
# 1995              215
# 1996              258
# 1997              282
# 1998              364
# 1999              326
# 2000              325
# 2001              428
# 2002              631
# 2003              546
# 2004              550
# 2005              657
# 2006              773
# 2007              884
# 2008             1039
# 2009             1001
# 2010              900
# 2011              779
# 2012              446
# 2013              335
# 2014              319
# 2015              362
# 2016              297

# %%
anual_platform_sales = games.pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'sum')
anual_platform_sales
# Out:
# platform          2600   3DO    3DS    DC      DS     GB    GBA     GC    GEN  \
# year_of_release
# 1980             11.38   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1981             35.68   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1982             28.88   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1983              5.84   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1984              0.27   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1985              0.45   NaN    NaN   NaN    0.02    NaN    NaN    NaN    NaN
# 1986              0.67   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1987              1.94   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1988              0.74   NaN    NaN   NaN     NaN   1.43    NaN    NaN    NaN
# 1989              0.63   NaN    NaN   NaN     NaN  64.97    NaN    NaN    NaN
# 1990               NaN   NaN    NaN   NaN     NaN   4.89    NaN    NaN   2.60
# ...

# %%
anual_platform_sales.plot(kind='bar', figsize = (15,15), grid=True, title='Суммарные продажи для платформ по годам',
                   xlabel = 'год выпуска игр', ylabel='суммарные продажи');

# %% [markdown]
# #### Период жизни платформ

# %% [markdown]
# Рассмотрим `период жизни` платформ

# %%
platform_lifetime= games.pivot_table(index =  'platform',  values = 'year_of_release', aggfunc =('min', 'max'))
platform_lifetime['lifetime']=platform_lifetime['max']-platform_lifetime['min']
platform_lifetime=platform_lifetime.sort_values(by='min')
platform_lifetime
# Out:
#            max   min  lifetime
# platform
# 2600      1989  1980         9
# NES       1994  1983        11
# DS        2013  1985        28
# PC        2016  1985        31
# GB        2001  1988        13
# SNES      1999  1990         9
# GEN       1994  1990         4
# GG        1992  1992         0
# SCD       1994  1993         1
# NG        1996  1993         3
# SAT       1999  1994         5
# PS        2003  1994         9
# 3DO       1995  1994         1
# TG16      1995  1995         0
# PCFX      1996  1996         0
# N64       2002  1996         6
# DC        2008  1998        10
# WS        2001  1999         2
# GBA       2007  2000         7
# XB        2008  2000         8
# PS2       2011  2000        11
# GC        2007  2001         6
# PSP       2015  2004        11
# X360      2016  2005        11
# PS3       2016  2006        10
# Wii       2016  2006        10
# 3DS       2016  2011         5
# PSV       2016  2011         5
# ...

# %% [markdown]
# Ожидаемо, долгожителем среди платформ является ПК. Также теперь заметно, что некоторые платформы прожили меньше года, скорей всего это непопулярные платформы, выпуск игр на которые показал себя нерентабельным и проект свернули. Основная часть таких платформ выпускались в 90е годы, в период развития индустрии. и именно данные этих платформ меньше всего подходят для анализа. Для начала избависмя от них в таблице `platform_lifetime` для того, чтобы минимизировать погрешность в вычислении средней продолжительности `жизни` платформы, заодно избавимся и от платформ, проживших один год, тоже те еще конкуренты на рынке.

# %%
platform_lifetime=platform_lifetime.query('31 > lifetime > 1')
platform_lifetime
# Out:
#            max   min  lifetime
# platform
# 2600      1989  1980         9
# NES       1994  1983        11
# DS        2013  1985        28
# GB        2001  1988        13
# SNES      1999  1990         9
# GEN       1994  1990         4
# NG        1996  1993         3
# SAT       1999  1994         5
# PS        2003  1994         9
# N64       2002  1996         6
# DC        2008  1998        10
# WS        2001  1999         2
# GBA       2007  2000         7
# XB        2008  2000         8
# PS2       2011  2000        11
# GC        2007  2001         6
# PSP       2015  2004        11
# X360      2016  2005        11
# PS3       2016  2006        10
# Wii       2016  2006        10
# 3DS       2016  2011         5
# PSV       2016  2011         5
# WiiU      2016  2012         4
# PS4       2016  2013         3
# XOne      2016  2013         3

# %% [markdown]
# Теперь рассчитаем среднюю продолжительность жизни платформы

# %%
print('Средняя продолжительность жизни консоли:',platform_lifetime['lifetime'].mean())
# Out:
# Средняя продолжительность жизни консоли: 8.12

# %% [markdown]
# похоже, что средняя продолжительность жизни платформы составляет `8.12` лет. Долгожители ПК тут в рассчет не берутся, поскольку под названием ПК прячется долгий процесс эволюции железа от хлебушка до нынешних 'вундервафель' с неоном и водяным охлаждением, просто будем иметь в виду, что ПК был всегда, для остальных же платформ, продолжительность жизни будем считать ~ 8 лет.

# %% [markdown]
# #### Популярные платформы

# %% [markdown]
# Вернемся  нашему вопросу.

# %% [markdown]
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# Теперь мы знаем, что платформа живет в среднем 8.12 лет. Кроме того, мы знаем что ориентировочно в 2011-2013 году произошла смена поколений консолей. Исходя из этого, стоит понимать, что нам нужны не только платформы с наибольшим показатлем продаж, но и платформы, текущего поколения, т.е 2011-2016 года. Поэтому нужно взять двойное условие `платформа попадает в топ 10 по суммарным продажам` **или** ` игры на платформу выходят в период 2011-2016 гг`. Посмотрим, что получится.

# %%
mean_sales_per_year =games.pivot_table(index = 'year_of_release',  values = 'total_sales', aggfunc = 'mean')
mean_sales_per_year.plot(kind='bar', figsize = (15,15), grid=True, title='Средние продажи игр по годам',
                   xlabel = 'год выпуска игр', ylabel='средние продажи');

# %% [markdown]
# На графике средних продажи игр по годам 2011 год не выделяется, что говорит о том, что дело не в одной игре, на которую был рекордный спрос. тут дело в том, что в 2007-2011 году индустрия пережила повышенное внимание инвесторов, появилось большое количество студий, рынок разросся, выспускалось очень большое количество игр. именно с этим и связаны большие суммарные продажи.

# %% [markdown]
# Рассмотрим количествоигр, выпущенных в 2011 и 2012 годы

# %%
print('Количество игр, выпущенных в 2011 году:',games.query('year_of_release == 2011')['name'].nunique())
print('Количество игр, выпущенных в 2012 году:',games.query('year_of_release == 2012')['name'].nunique())
# Out:
# Количество игр, выпущенных в 2011 году: 779
# Количество игр, выпущенных в 2012 году: 446

# %% [markdown]
# Игр в 2011 году выпустили вдвое больше

# %%
def list_former(series):
    list=[]
    for item in series:
        list.append(item)
    return list

# %%
top_platform_sales=anual_platform.sort_values(by='total_sales', ascending=False)
top_platform_sales=top_platform_sales.reset_index()
top_ten=top_platform_sales['platform'][0:10]
top_ten=list_former(top_ten)
top_ten
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'PS4', 'GBA', 'PSP', '3DS']

# %% [markdown]
# А вот и список самых популярных платформ. Теперь найдем платформы, выпущенные после 2011 года

# %%
platform_lifetime=platform_lifetime.reset_index()
newest_generation = platform_lifetime[platform_lifetime['min']>= 2012]['platform']
newest_generation=list_former(newest_generation)
newest_generation
# Out:
# ['WiiU', 'PS4', 'XOne']

# %% [markdown]
# Платформы нового поколения тоже нашли, пора выводить данные по ежегодным продажам, посмотрим как они распределяются.

# %% [markdown]
# Создадим общий список и избавимся от дубликатов

# %%
def list_sorter(list_1,list_2):
    list_1
    for item in list_2:
        if item not in list_1:
            list_1.append(item)
    return list_1

# %%
sorted_list = list_sorter(top_ten,newest_generation)
sorted_list
# Out:
# ['PS2',
#  'X360',
#  'PS3',
#  'Wii',
#  'DS',
#  'PS',
#  'PS4',
#  'GBA',
#  'PSP',
#  '3DS',
#  'WiiU',
#  'XOne']

# %% [markdown]
# Не забудем 'вечный' ПК который мы отсеяли для более точного анализа продолжительности жизни платформ.

# %%
sorted_list.append('PC')

# %%
sorted_list=pd.DataFrame(sorted_list)
sorted_list['place']= 1
sorted_list.rename(columns={0: 'platform'}, inplace=True)
sorted_list
# Out:
#    platform  place
# 0       PS2      1
# 1      X360      1
# 2       PS3      1
# 3       Wii      1
# 4        DS      1
# 5        PS      1
# 6       PS4      1
# 7       GBA      1
# 8       PSP      1
# 9       3DS      1
# 10     WiiU      1
# 11     XOne      1
# 12       PC      1

# %% [markdown]
# Перезапишем таблицу `anual_platform_sales` по новым вводным

# %%
analised_platforms = games.merge(sorted_list, on='platform',how='inner')
analised_platforms['platform'].unique()
# Out:
# array(['Wii', 'DS', 'X360', 'PS3', 'PS2', 'GBA', 'PS4', '3DS', 'PS', 'PC',
#        'PSP', 'XOne', 'WiiU'], dtype=object)

# %%
anual_platform_sales = (
    analised_platforms
    .pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'sum'))
anual_platform_sales
# Out:
# platform           3DS      DS    GBA     PC      PS     PS2     PS3     PS4  \
# year_of_release
# 1985               NaN    0.02    NaN   0.04     NaN     NaN     NaN     NaN
# 1988               NaN     NaN    NaN   0.03     NaN     NaN     NaN     NaN
# 1992               NaN     NaN    NaN   3.03     NaN     NaN     NaN     NaN
# 1994               NaN     NaN    NaN  12.87    6.03     NaN     NaN     NaN
# 1995               NaN     NaN    NaN   4.22   35.96     NaN     NaN     NaN
# 1996               NaN     NaN    NaN  10.58   94.70     NaN     NaN     NaN
# 1997               NaN     NaN    NaN  11.27  136.17     NaN     NaN     NaN
# 1998               NaN     NaN    NaN   3.26  169.49     NaN     NaN     NaN
# 1999               NaN     NaN    NaN   4.74  144.53     NaN     NaN     NaN
# 2000               NaN     NaN   0.07   4.66   96.37   39.17     NaN     NaN
# 2001               NaN     NaN  61.53   5.47   35.59  166.43     NaN     NaN
# ...

# %%
anual_platform_sales.plot(kind='bar', figsize = (15,15), width=2, grid=True, title='Суммарные продажи по  популярным платформам',
                   xlabel = 'год выпуска игр', ylabel='суммарные продажи');

# %% [markdown]
# Однако данная гистограмма отображает суммарные продажи по всем играм консоли, а что будет, если рассчитать среднее количество продаж на игру платформы?

# %%
anual_platform_shares = (
    analised_platforms
    .pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'mean'))

# %%
anual_platform_shares.plot(kind='bar', figsize = (15,15), width=2, grid=True, title='Среднее количество продаж на игру по платформам',
                   xlabel = 'год выпуска игр', ylabel='среднее количество продаж');

# %% [markdown]
# А вот это уже интересно, похоже, что в 2006 году Wii пользовалась невероятной популярностью, не смотря на то, что игр на нее выходило не так уж много, количество продаж на игру в разы превышало показатели по прочим платформам. И это в первый год релиза. Интересно, связано ли это с тем, что платформа имела обратную совместимость с играми предыдущего поколения. Однако, резкий скачек популярности Wii не привел к ее полному доминированию на рынке и в последующие годы, количество продаж на игру пришло в норму (к среднему по рынку)

# %% [markdown]
# ### Актуальный период

# %% [markdown]
# Чтож, пора определяться с актуальным периодом и отфильтровать данные по интересующим нас годам.
#
# В топе десяти самых популярных консолей фигурируют как консоли 80х, так и современные консоли. Мы определили, что поколения сменяются в течении 8 лет, кроме того, последняя смена поколений произошла где-то в районе 2011 года. Это говорит о том, что поколение 2011 года сейчас ведет конкурентную борьбу на рынке. Определим актуальный период как период с 2011 по 2016 года

# %%
sorted_games = games.query('year_of_release >= 2012')
sorted_games
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34        Call of Duty: Black Ops II      PS3             2012       Shooter
# ...                              ...      ...              ...           ...
# 16434               Aiyoku no Eustia      PSV             2014          Misc
# 16437  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16439        Haitaka no Psychedelica      PSV             2016     Adventure
# 16441            Winning Post 8 2016      PSV             2016    Simulation
# 16442                  Madden NFL 13      PS3             2012        Sports
#
# ...

# %%
sorted_games['platform'].nunique()
# Out:
# 11

# %%
sorted_platform_shares = (
    sorted_games
    .pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'mean'))

# %%
sorted_platform_shares.plot(kind='bar', figsize = (15,15), width=0.5, grid=True, 
                            title='Среднее количество продаж на игру по платформам за актуальный преиод', 
                            xlabel = 'год выпуска игр', ylabel='среднее количество продаж', colormap="turbo");

# %% [markdown]
# Наибольшими продажами с момента выхода отличается PS4, но даже по ней спрос на игры начинает резко падать со временем. Похоже, что 2013 год был пиковым по спросу на рынке компьютерных игр, возможно это цикличное явление и для каждого поколения консолей существует пик спроса, не удивлюсь, если это связано с тем, что наиболее популярные разработчики придерживают свои крупные проекты, чтобы не выпускать их на свежую консоль, рискуя быть заваленными багрепортами и негативными отзывами.

# %% [markdown]
# ### Определение потенциально прибыльных платформ

# %% [markdown]
# Пора определить платформы, продолжающие конкуренцию на рынке на момент 2016 года, для этого отфильтруем значения таблицы `platform_lifetime` по максимальному году выпуска игр.

# %%
reliese_period=games.pivot_table(index =  'platform',  values = 'year_of_release', aggfunc =('min', 'max'))
actual_competitors=reliese_period[reliese_period['max']==2016]
actual_competitors=actual_competitors.reset_index()
actual_competitors
# Out:
#   platform   max   min
# 0      3DS  2016  2011
# 1       PC  2016  1985
# 2      PS3  2016  2006
# 3      PS4  2016  2013
# 4      PSV  2016  2011
# 5      Wii  2016  2006
# 6     WiiU  2016  2012
# 7     X360  2016  2005
# 8     XOne  2016  2013

# %% [markdown]
# Можем отбросить уже ушедшие с рынка платформы, они выбыли из конкуренции.

# %%
competition=actual_competitors[['platform','max']]
sorted_games = sorted_games.merge(competition, on='platform',how='inner')
sorted_games
# Out:
#                             name platform  year_of_release       genre  \
# 0             Grand Theft Auto V      PS3             2013      Action
# 1     Call of Duty: Black Ops II      PS3             2012     Shooter
# 2           Call of Duty: Ghosts      PS3             2013     Shooter
# 3                 FIFA Soccer 13      PS3             2012      Action
# 4                        FIFA 14      PS3             2013      Sports
# ...                          ...      ...              ...         ...
# 2676       The Longest 5 Minutes      PSV             2016      Action
# 2677            Strawberry Nauts      PSV             2016   Adventure
# 2678            Aiyoku no Eustia      PSV             2014        Misc
# 2679     Haitaka no Psychedelica      PSV             2016   Adventure
# 2680         Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %%
sorted_platform_shares = (
    sorted_games
    .pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'mean'))
sorted_platform_shares.plot(kind='bar', figsize = (15,15), width=0.5, grid=True,
                            title='Среднее количество продаж для актуальных платформ', 
                            xlabel = 'год выпуска игр', ylabel='среднее количество продаж', colormap="turbo");

# %%
sorted_games['platform'].nunique()
# Out:
# 9

# %% [markdown]
# Итак, мы свели количество конкурирующих приставок в датафрейме до 9, оставив только те, которые представлены на рынке на актуальный период и ведут активную разработку игр. Заодно ответили на вопрос какие платформы потенциально могут принести прибыль в 2017 году.

# %% [markdown]
# Определим суммарное количество продаж по годам для консолей, ведущих конкуренцию на рынке

# %%
sorted_platform_sales = (
    sorted_games
    .pivot_table(index = 'year_of_release',  columns = 'platform',values = 'total_sales', aggfunc = 'sum'))
sorted_platform_sales
# Out:
# platform           3DS     PC     PS3     PS4    PSV    Wii   WiiU   X360  \
# year_of_release
# 2012             51.36  23.22  107.36     NaN  16.19  21.71  17.56  99.74
# 2013             56.57  12.38  113.25   25.99  10.59   8.59  21.65  88.58
# 2014             43.76  13.28   47.76  100.00  11.90   3.75  22.03  34.74
# 2015             27.78   8.52   16.82  118.90   6.25   1.14  16.35  11.96
# 2016             15.14   5.25    3.60   69.25   4.25   0.18   4.60   1.52
#
# platform          XOne
# year_of_release
# 2012               NaN
# 2013             18.96
# 2014             54.07
# 2015             60.14
# 2016             26.15

# %%
sorted_platform_sales.plot(kind='bar', figsize = (15,15), width=0.5, grid=True,  
                           title='Суммарное количество продаж на игру по лидирующим на рынке платформам за актуальный преиод', 
                           xlabel = 'год выпуска игр', ylabel='суммарное количество продаж');

# %% [markdown]
# Общая тенденция рынка на момент 2016 года - падение количества продаж на всех платформах. В период 2012-2013 года на рынке лидировала PS3, конкурируя с Xbox360, в 2013 году Sony и MS практически одновременно выпустили PS4 и XboxOne. Уже в 2013 году обе эти платформы вырываются в лидеры по продажам, правда в 2013 году Xbox360 еще не потерял свою актуальность, а так же, возможно, сказалось малое количество выпущенных за год игр на XboxOne, поэтому в 2013 году XboxOne все еще уступает по продажам Xbox360, но к 2014 году, он начинает выдавливать Xbox360 с рынка по доле. Однако, в 2014 году продажи по всем платформам, в том числе и новым, начинают падать.

# %% [markdown]
# Будем считать, что перспективные консоли - топ 3 по спросу за 2016 год. Они выдержали проверку временем, заняли свои ниши и продолжают приносить прибыль.
# PS4, XboxOne и Nintendo3DS

# %% [markdown]
# ### Распределение продаж игр по платформам

# %%
import matplotlib.pyplot as plt
import seaborn as sns



fig, axes = plt.subplots(1,figsize=(10, 10))

#sns.distplot(smart_analise['gb_total'], kde=False, ax=axes[0]);
#sns.distplot(ultra_analise['gb_total'], kde=False, ax=axes[0]);

sns.boxplot(x=sorted_games['platform'], y = sorted_games['total_sales']);
plt.ylim(0, 2);

# %%
sorted_games.query('platform == "3DS"')['total_sales'].describe()
# Out:
# count    396.000000
# mean       0.491439
# std        1.387161
# min        0.010000
# 25%        0.040000
# 50%        0.110000
# 75%        0.312500
# max       14.600000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "PC"')['total_sales'].describe()
# Out:
# count    250.00000
# mean       0.25060
# std        0.49464
# min        0.01000
# 25%        0.03000
# 50%        0.08000
# 75%        0.24000
# max        5.14000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "PS3"')['total_sales'].describe()
# Out:
# count    492.000000
# mean       0.586972
# std        1.464141
# min        0.010000
# 25%        0.050000
# 50%        0.200000
# 75%        0.610000
# max       21.050000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "PS4"')['total_sales'].describe()
# Out:
# count    392.000000
# mean       0.801378
# std        1.609456
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.730000
# max       14.630000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "PSV"')['total_sales'].describe()
# Out:
# count    411.000000
# mean       0.119659
# std        0.203011
# min        0.010000
# 25%        0.020000
# 50%        0.050000
# 75%        0.120000
# max        1.960000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "Wii"')['total_sales'].describe()
# Out:
# count    54.000000
# mean      0.655000
# std       1.165447
# min       0.010000
# 25%       0.062500
# 50%       0.180000
# 75%       0.687500
# max       6.760000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "WiiU"')['total_sales'].describe()
# Out:
# count    147.000000
# mean       0.559116
# std        1.058836
# min        0.010000
# 25%        0.080000
# 50%        0.220000
# 75%        0.525000
# max        7.090000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "X360"')['total_sales'].describe()
# Out:
# count    292.000000
# mean       0.810068
# std        1.712069
# min        0.010000
# 25%        0.100000
# 50%        0.310000
# 75%        0.870000
# max       16.270000
# Name: total_sales, dtype: float64

# %%
sorted_games.query('platform == "XOne"')['total_sales'].describe()
# Out:
# count    247.000000
# mean       0.645020
# std        1.036139
# min        0.010000
# 25%        0.060000
# 50%        0.220000
# 75%        0.685000
# max        7.390000
# Name: total_sales, dtype: float64

# %% [markdown]
# Большая часть выходящих на платформы игр, судя по ящику с усами, продаются небольшим тиражом, в районе 200 тысяч копий. Выбросы, находящиеся за пределами нормального распределения - `ААА тайтлы` (игры с огромным бюджетом, в том числе на разработку и рекламу, выходящие на большое количество платформ, продажи от которых, окупают подобные затраты).

# %%
sorted_games.query('total_sales > 15')
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 0    Grand Theft Auto V      PS3             2013  Action      7.02      9.09
# 492  Grand Theft Auto V     X360             2013  Action      9.66      5.14
#
#      jp_sales  other_sales  critic_score user_score rating  total_sales   max
# 0        0.98         3.96          97.0        8.2      M        21.05  2016
# 492      0.06         1.41          97.0        8.1      M        16.27  2016

# %% [markdown]
# К примеру, больше 15 млн. копий по всем регионам собрала только `GTA V` на каждой из двух платформ (зная будущее, количество платформ, на которых выйдет GTA V, станет гораздо больше). На сегодняшний день, игра уже вышла на третье поколение консолей.

# %% [markdown]
# В данном случае, будет некорректно удалить игры, находящиеся за границами нормального распределения, так как они представляютотдельный сегмент рынка, который, при необходимости, можно рассматривать отдельно.

# %% [markdown]
# ### Зависимость продаж по платформе от отзывов пользователей и критиков

# %%
sorted_score = (
    sorted_games
    .pivot_table(index = 'platform', values = ['critic_score','user_score'], aggfunc = 'count'))
sorted_score
# Out:
#           critic_score  user_score
# platform
# 3DS                104         143
# PC                 198         211
# PS3                213         308
# PS4                252         263
# PSV                107         137
# Wii                  5          34
# WiiU                90         105
# X360               171         246
# XOne               169         193

# %% [markdown]
# #### По платформе PS3

# %% [markdown]
# Выберем `PS3` как самую популярную платформу с наибольшим количеством оценок критиков и пользователей.

# %%
PS3_scores =  sorted_games.query('platform == "PS3"')
PS3_scores
# Out:
#                               name platform  year_of_release    genre  \
# 0               Grand Theft Auto V      PS3             2013   Action
# 1       Call of Duty: Black Ops II      PS3             2012  Shooter
# 2             Call of Duty: Ghosts      PS3             2013  Shooter
# 3                   FIFA Soccer 13      PS3             2012   Action
# 4                          FIFA 14      PS3             2013   Sports
# ..                             ...      ...              ...      ...
# 487            Tour de France 2014      PS3             2014   Sports
# 488  Tsukigime Ranko's Longest Day      PS3             2014   Action
# 489   Dynasty Warriors: Eiketsuden      PS3             2016   Action
# 490  Samurai Warriors: Sanada Maru      PS3             2016   Action
# 491                  Madden NFL 13      PS3             2012   Sports
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %%
PS3_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             492 non-null    object
#  1   platform         492 non-null    object
#  2   year_of_release  492 non-null    int32
#  3   genre            492 non-null    object
#  4   na_sales         492 non-null    float64
#  5   eu_sales         492 non-null    float64
#  6   jp_sales         492 non-null    float64
#  7   other_sales      492 non-null    float64
#  8   critic_score     213 non-null    float64
#  9   user_score       308 non-null    object
#  10  rating           299 non-null    object
#  11  total_sales      492 non-null    float64
#  12  max              492 non-null    int32
# dtypes: float64(6), int32(2), object(5)
# memory usage: 50.0+ KB

# %%
PS3_scores.plot(x='critic_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки критиков:', PS3_scores['total_sales'].corr(PS3_scores['critic_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки критиков: 0.3341655878702379

# %%
import warnings
warnings.simplefilter("ignore")

# %%
#PS3_scores=PS3_scores[PS3_scores['user_score'] == 'tbd'] = 0
PS3_scores.loc[PS3_scores['user_score'] == 'tbd', 'user_score'] = 0
PS3_scores
# Out:
#                               name platform  year_of_release    genre  \
# 0               Grand Theft Auto V      PS3             2013   Action
# 1       Call of Duty: Black Ops II      PS3             2012  Shooter
# 2             Call of Duty: Ghosts      PS3             2013  Shooter
# 3                   FIFA Soccer 13      PS3             2012   Action
# 4                          FIFA 14      PS3             2013   Sports
# ..                             ...      ...              ...      ...
# 487            Tour de France 2014      PS3             2014   Sports
# 488  Tsukigime Ranko's Longest Day      PS3             2014   Action
# 489   Dynasty Warriors: Eiketsuden      PS3             2016   Action
# 490  Samurai Warriors: Sanada Maru      PS3             2016   Action
# 491                  Madden NFL 13      PS3             2012   Sports
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %%
PS3_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             492 non-null    object
#  1   platform         492 non-null    object
#  2   year_of_release  492 non-null    int32
#  3   genre            492 non-null    object
#  4   na_sales         492 non-null    float64
#  5   eu_sales         492 non-null    float64
#  6   jp_sales         492 non-null    float64
#  7   other_sales      492 non-null    float64
#  8   critic_score     213 non-null    float64
#  9   user_score       308 non-null    object
#  10  rating           299 non-null    object
#  11  total_sales      492 non-null    float64
#  12  max              492 non-null    int32
# dtypes: float64(6), int32(2), object(5)
# memory usage: 50.0+ KB

# %%
PS3_scores['user_score']=pd.to_numeric(PS3_scores['user_score'], errors='coerce')
PS3_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 0 to 491
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             492 non-null    object
#  1   platform         492 non-null    object
#  2   year_of_release  492 non-null    int32
#  3   genre            492 non-null    object
#  4   na_sales         492 non-null    float64
#  5   eu_sales         492 non-null    float64
#  6   jp_sales         492 non-null    float64
#  7   other_sales      492 non-null    float64
#  8   critic_score     213 non-null    float64
#  9   user_score       308 non-null    float64
#  10  rating           299 non-null    object
#  11  total_sales      492 non-null    float64
#  12  max              492 non-null    int32
# dtypes: float64(7), int32(2), object(4)
# memory usage: 50.0+ KB

# %%
PS3_scores.plot(x='user_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки пользователей:', PS3_scores['total_sales'].corr(PS3_scores['user_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки пользователей: 0.09416096319917433

# %% [markdown]
# Оценка критиков имеет слабое прямое влиияние на количество продаж, что понятно, поскольку при покупке игры, пользователи могут обратить внимание на оценку критиков. Оценка же пользователей практические не влияет на продажи, поскольку пользователи редко берут во внимание субъективный опыт других пользователей и предпочитают исходить из своих вкусов.

# %% [markdown]
# #### По всем платформам

# %% [markdown]
# Рассмотрим зависимость продаж от оценок по всем платформам.

# %%
all_scores =  sorted_games.copy(deep=True)
all_scores['user_score']=pd.to_numeric(all_scores['user_score'], errors='coerce')
all_scores
# Out:
#                             name platform  year_of_release       genre  \
# 0             Grand Theft Auto V      PS3             2013      Action
# 1     Call of Duty: Black Ops II      PS3             2012     Shooter
# 2           Call of Duty: Ghosts      PS3             2013     Shooter
# 3                 FIFA Soccer 13      PS3             2012      Action
# 4                        FIFA 14      PS3             2013      Sports
# ...                          ...      ...              ...         ...
# 2676       The Longest 5 Minutes      PSV             2016      Action
# 2677            Strawberry Nauts      PSV             2016   Adventure
# 2678            Aiyoku no Eustia      PSV             2014        Misc
# 2679     Haitaka no Psychedelica      PSV             2016   Adventure
# 2680         Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
all_scores.plot(x='critic_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки критиков:', all_scores['total_sales'].corr(all_scores['critic_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки критиков: 0.3086708796259362

# %%
all_scores.plot(x='user_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки пользователей:', all_scores['total_sales'].corr(all_scores['user_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки пользователей: 0.003701317128135152

# %% [markdown]
# По всем остальным платформам, наблюдается та же картина, что и при рассмотрении PS3. Оценка критиков имеет слабое прямое влиияние на количество продаж, а оценка пользователей практически не влияет на продажи.

# %% [markdown]
# #### По платформе X360

# %% [markdown]
# Рассмотрим `X360` как вторую популярную платформу с наибольшим количеством оценок критиков и пользователей.

# %%
X360_scores =  sorted_games.query('platform == "X360"')
X360_scores
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 492          Grand Theft Auto V     X360             2013    Action      9.66
# 493  Call of Duty: Black Ops II     X360             2012   Shooter      8.25
# 494        Call of Duty: Ghosts     X360             2013   Shooter      6.73
# 495                      Halo 4     X360             2012   Shooter      6.65
# 496                   Minecraft     X360             2013      Misc      5.70
# ..                          ...      ...              ...       ...       ...
# 779    Turbo: Super Stunt Squad     X360             2013    Sports      0.00
# 780       Young Justice: Legacy     X360             2013    Action      0.00
# 781                        Ride     X360             2015    Racing      0.00
# 782    Dragon Ball Z for Kinect     X360             2012  Fighting      0.01
# 783          Ben 10 Omniverse 2     X360             2013    Action      0.00
#
# ...

# %%
X360_scores.plot(x='critic_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки критиков:', X360_scores['total_sales'].corr(X360_scores['critic_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки критиков: 0.36057348885073387

# %%
X360_scores.loc[X360_scores['user_score'] == 'tbd', 'user_score'] = 0
X360_scores['user_score']=pd.to_numeric(X360_scores['user_score'], errors='coerce')
X360_scores
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 492          Grand Theft Auto V     X360             2013    Action      9.66
# 493  Call of Duty: Black Ops II     X360             2012   Shooter      8.25
# 494        Call of Duty: Ghosts     X360             2013   Shooter      6.73
# 495                      Halo 4     X360             2012   Shooter      6.65
# 496                   Minecraft     X360             2013      Misc      5.70
# ..                          ...      ...              ...       ...       ...
# 779    Turbo: Super Stunt Squad     X360             2013    Sports      0.00
# 780       Young Justice: Legacy     X360             2013    Action      0.00
# 781                        Ride     X360             2015    Racing      0.00
# 782    Dragon Ball Z for Kinect     X360             2012  Fighting      0.01
# 783          Ben 10 Omniverse 2     X360             2013    Action      0.00
#
# ...

# %%
X360_scores.plot(x='user_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки пользователей:', X360_scores['total_sales'].corr(X360_scores['user_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки пользователей: 0.062214862925322405

# %% [markdown]
# Оценка критиков имеет слабое прямое влиияние на количество продаж, что понятно, поскольку при покупке игры, пользователи могут обратить внимание на оценку критиков. Оценка же пользователей практические не влияет на продажи, поскольку пользователи редко берут во внимание субъективный опыт других пользователей и предпочитают исходить из своих вкусов.

# %% [markdown]
# #### По PC

# %% [markdown]
# Рассмотрим `PC` как третью популярную платформу с наибольшим количеством оценок критиков и пользователей.

# %%
PC_scores =  sorted_games.query('platform == "PC"')
PC_scores
# Out:
#                                        name platform  year_of_release  \
# 2020                             Diablo III       PC             2012
# 2021                             The Sims 4       PC             2014
# 2022                           Guild Wars 2       PC             2012
# 2023   World of Warcraft: Mists of Pandaria       PC             2012
# 2024       StarCraft II: Heart of the Swarm       PC             2013
# ...                                     ...      ...              ...
# 2265        Transformers: Fall of Cybertron       PC             2012
# 2266  Codename: Panzers Complete Collection       PC             2016
# 2267        The Amazing Spider-Man 2 (2014)       PC             2014
# 2268                         End of Nations       PC             2012
# 2269      Metal Gear Solid V: Ground Zeroes       PC             2014
#
#              genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
PC_scores.plot(x='critic_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки критиков:', PC_scores['total_sales'].corr(PC_scores['critic_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки критиков: 0.23724324311567907

# %%
PC_scores.loc[PC_scores['user_score'] == 'tbd', 'user_score'] = 0
PC_scores['user_score']=pd.to_numeric(PC_scores['user_score'], errors='coerce')
PC_scores
# Out:
#                                        name platform  year_of_release  \
# 2020                             Diablo III       PC             2012
# 2021                             The Sims 4       PC             2014
# 2022                           Guild Wars 2       PC             2012
# 2023   World of Warcraft: Mists of Pandaria       PC             2012
# 2024       StarCraft II: Heart of the Swarm       PC             2013
# ...                                     ...      ...              ...
# 2265        Transformers: Fall of Cybertron       PC             2012
# 2266  Codename: Panzers Complete Collection       PC             2016
# 2267        The Amazing Spider-Man 2 (2014)       PC             2014
# 2268                         End of Nations       PC             2012
# 2269      Metal Gear Solid V: Ground Zeroes       PC             2014
#
#              genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
PC_scores.plot(x='user_score', y='total_sales', kind='scatter');

# %%
print('Коэффициент корреляции количества продаж от оценки пользователей:', PC_scores['total_sales'].corr(PC_scores['user_score']))
# Out:
# Коэффициент корреляции количества продаж от оценки пользователей: -0.0656472863944798

# %% [markdown]
# Оценка критиков имеет слабое прямое влиияние на количество продаж, что понятно, поскольку при покупке игры, пользователи могут обратить внимание на оценку критиков. Оценка же пользователей практические не влияет на продажи, поскольку пользователи редко берут во внимание субъективный опыт других пользователей и предпочитают исходить из своих вкусов.

# %% [markdown]
# Рассмотрев несколько популярных платформ с большим количеством оценок критиков и пользователей, можно сказать что выводы, наблюдаемые на PS3, подтверждаются по другим платформам.

# %% [markdown]
# ### Общее распределение игр по жанрам

# %%
genre_pivot = sorted_games.pivot_table(index = 'genre', values = 'total_sales', aggfunc = ['sum','count', 'mean'])
genre_pivot
# Out:
#                      sum       count        mean
#              total_sales total_sales total_sales
# genre
# Action            435.54         953    0.457020
# Adventure          27.70         247    0.112146
# Fighting           44.13         105    0.420286
# Misc               84.15         180    0.467500
# Platform           60.31          83    0.726627
# Puzzle              4.79          24    0.199583
# Racing             53.50         115    0.465217
# Role-Playing      180.91         339    0.533658
# Shooter           304.73         235    1.296723
# Simulation         34.85          78    0.446795
# Sports            179.55         255    0.704118
# Strategy           12.63          67    0.188507

# %%
genre_pivot.columns = ['total_sales', 'number_of_games', 'sales_per_game'] 
genre_pivot
# Out:
#               total_sales  number_of_games  sales_per_game
# genre
# Action             435.54              953        0.457020
# Adventure           27.70              247        0.112146
# Fighting            44.13              105        0.420286
# Misc                84.15              180        0.467500
# Platform            60.31               83        0.726627
# Puzzle               4.79               24        0.199583
# Racing              53.50              115        0.465217
# Role-Playing       180.91              339        0.533658
# Shooter            304.73              235        1.296723
# Simulation          34.85               78        0.446795
# Sports             179.55              255        0.704118
# Strategy            12.63               67        0.188507

# %%
genre_pivot.sort_values(by='total_sales', ascending = False)
# Out:
#               total_sales  number_of_games  sales_per_game
# genre
# Action             435.54              953        0.457020
# Shooter            304.73              235        1.296723
# Role-Playing       180.91              339        0.533658
# Sports             179.55              255        0.704118
# Misc                84.15              180        0.467500
# Platform            60.31               83        0.726627
# Racing              53.50              115        0.465217
# Fighting            44.13              105        0.420286
# Simulation          34.85               78        0.446795
# Adventure           27.70              247        0.112146
# Strategy            12.63               67        0.188507
# Puzzle               4.79               24        0.199583

# %%
genre_pivot.sort_values(by='number_of_games', ascending = False)
# Out:
#               total_sales  number_of_games  sales_per_game
# genre
# Action             435.54              953        0.457020
# Role-Playing       180.91              339        0.533658
# Sports             179.55              255        0.704118
# Adventure           27.70              247        0.112146
# Shooter            304.73              235        1.296723
# Misc                84.15              180        0.467500
# Racing              53.50              115        0.465217
# Fighting            44.13              105        0.420286
# Platform            60.31               83        0.726627
# Simulation          34.85               78        0.446795
# Strategy            12.63               67        0.188507
# Puzzle               4.79               24        0.199583

# %%
genre_pivot.plot(kind='bar', figsize = (15,15), width=0.5, grid=True, title='Распределение игр по жанрам', 
                           xlabel = 'жанр', ylabel='продажи');

# %%
(genre_pivot.sort_values(by='sales_per_game', ascending = False)
 .plot(y='sales_per_game', kind='bar', figsize = (15,15), width=0.5, grid=True,title='Среднее количество продаж на игру по жанру', 
       xlabel = 'жанр', ylabel='среднее количество продаж'));

# %% [markdown]
# Самым прибыльным жанром по количеству продаж является жанр `Action`, однако если рассмотреть соотношение количесва продаж и количество выпущенных игр, то действительно самым прибыльным, является жанр `Shooter`. Следом за ним идут жанры `Platform` и `Sports` - игры на компанию, детей и для легкого времяпрепровождения. В дальнейшем будем рассматривать именно долю продаж на игру.

# %% [markdown]
# Самые высокие продажи, свыше 500 тыс. копий на игру, приходятся на жанры `Shooter`, `Platform` ,`Sports`.
#
# Игры с самым низким количеством продаж, менее 200 тыс. копий на игру, приходятся на жанры `Adventure`, `Strategy` ,`Puzzle`. По ним по всем можно дать обяснение.
# - жанр `Adventure` - нишевый жанр, не пользующийся особым спросом.
# - жанр `Strategy` - ранее популярный жанр, уступивший место более продвинутым и предоставляющим больше возможностей другим жанрам, например таким как RPG.
# - жанр `Puzzle` - игр этого жанра выпускают мало, хороших среди них еще меньше. Большие студии предпочитают этим жанром не заниматься, поэтому при низком бюджете редко появляются хорошие игры данного жанра. Кроме того здесь за долю рынка приходится бороться с мобильными и браузерными играми.

# %% [markdown]
# ## Портерет пользователя каждого региона

# %% [markdown]
# - Определите для пользователя каждого региона (NA, EU, JP):
# -- Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# -- Самые популярные жанры (топ-5). Поясните разницу.
# -- Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# ### Самые популярные платформы (топ-5)

# %%
region_pivot = sorted_games.pivot_table(index = 'platform', 
                                        values = ['na_sales', 'eu_sales', 'jp_sales','total_sales'], aggfunc = 'sum').sort_values(by='total_sales')
region_pivot
# Out:
#           eu_sales  jp_sales  na_sales  total_sales
# platform
# Wii          11.92      3.39     17.45        35.37
# PSV          11.36     21.04     10.98        49.18
# PC           37.76      0.00     19.12        62.65
# WiiU         25.13     13.01     38.10        82.19
# XOne         51.59      0.34     93.12       159.32
# 3DS          42.64     87.79     55.31       194.61
# X360         74.52      1.57    140.05       236.54
# PS3         106.86     35.29    103.38       288.79
# PS4         141.09     15.96    108.74       314.14

# %%
region_pivot.plot(kind='bar', figsize = (15,10), width=0.5, grid=True);

# %%
eu_sales=region_pivot[['eu_sales', 'total_sales']].sort_values(by='eu_sales', ascending = False).head()
eu_sales
# Out:
#           eu_sales  total_sales
# platform
# PS4         141.09       314.14
# PS3         106.86       288.79
# X360         74.52       236.54
# XOne         51.59       159.32
# 3DS          42.64       194.61

# %%
eu_sales['eu_market_share'] = eu_sales['eu_sales']/ eu_sales['total_sales']
eu_sales
# Out:
#           eu_sales  total_sales  eu_market_share
# platform
# PS4         141.09       314.14         0.449131
# PS3         106.86       288.79         0.370027
# X360         74.52       236.54         0.315042
# XOne         51.59       159.32         0.323814
# 3DS          42.64       194.61         0.219105

# %%
eu_sales =eu_sales.drop(columns = ['eu_sales','total_sales'],axis = 1)

# %% [markdown]
# Топ 5 популярных платформ в Европе: PS3, PS4, X360, 3DS, PC. Заметно, что платформы нового поколения еще не набрали популярности в регионе: PS3 выше по рейтингу, чем PS4, вышедшего недавно XOne в топе вообще нет.

# %%
na_sales=region_pivot[['na_sales', 'total_sales']].sort_values(by='na_sales', ascending = False).head()
na_sales['na_market_share'] = na_sales['na_sales']/ na_sales['total_sales']
na_sales
# Out:
#           na_sales  total_sales  na_market_share
# platform
# X360        140.05       236.54         0.592077
# PS4         108.74       314.14         0.346151
# PS3         103.38       288.79         0.357976
# XOne         93.12       159.32         0.584484
# 3DS          55.31       194.61         0.284209

# %%
na_sales =na_sales.drop(columns = ['na_sales','total_sales'],axis = 1)

# %% [markdown]
# Топ 5 популярных платформ в Северной Америке: X360, PS3, PS4, XOne, 3DS. Здесь также платформы нового поколения еще не набрали популярности в регионе, однако американцы предпочитают XBox, который производится тамже.

# %%
jp_sales=region_pivot[['jp_sales', 'total_sales']].sort_values(by='jp_sales', ascending = False).head()
jp_sales['jp_market_share'] = jp_sales['jp_sales']/ jp_sales['total_sales']
jp_sales
# Out:
#           jp_sales  total_sales  jp_market_share
# platform
# 3DS          87.79       194.61         0.451107
# PS3          35.29       288.79         0.122200
# PSV          21.04        49.18         0.427816
# PS4          15.96       314.14         0.050805
# WiiU         13.01        82.19         0.158292

# %%
jp_sales =jp_sales.drop(columns = ['jp_sales','total_sales'],axis = 1)

# %% [markdown]
# Топ 5 популярных платформ в Японии: 3DS, PS3, PSV, PS4, WiiU. В Японии в основном предпочитают платформы японского производства. Характерно, большую часть топа платформ занимают портативные консоли,что говорит нам о том, что пользователи из Японии нередко предпочитают занимать время игрой, находясь вне дома.

# %%
market_shares = eu_sales.join([na_sales, jp_sales], how= 'outer')
market_shares
# Out:
#           eu_market_share  na_market_share  jp_market_share
# platform
# PS4              0.449131         0.346151         0.050805
# PS3              0.370027         0.357976         0.122200
# X360             0.315042         0.592077              NaN
# XOne             0.323814         0.584484              NaN
# 3DS              0.219105         0.284209         0.451107
# PSV                   NaN              NaN         0.427816
# WiiU                  NaN              NaN         0.158292

# %%
market_shares.plot(kind='bar', figsize = (15,5), width=0.5, grid=True);

# %% [markdown]
# Выделяются 3 сегмента рынка:
# - Более 50% рынка РС игр, приходится на европейский регион, хотя в самом регионе стоят на 5 месте.
# - В свою очередь, регион Северной Америки характерен повышенным спросом на X360 и Xone (отметим, что поскольку XOne - консоль нового поколения, со временем она начнет забирать на себя все большую долю рынка). И они занимают большую долю продаж на мировом рынке.
# - Для Японии же характерен портативный гейминг. Общая доля продаж игр на эти платформы приходится на этот регион.

# %% [markdown]
# ### Самые популярные жанры (топ-5)

# %%
eu_genre_sales=(sorted_games.pivot_table(index = 'genre', 
                                        values = 'eu_sales', aggfunc = 'sum')
                .sort_values(by='eu_sales', ascending = False).head())
eu_genre_sales
# Out:
#               eu_sales
# genre
# Action          158.43
# Shooter         113.47
# Sports           68.84
# Role-Playing     46.76
# Racing           27.29

# %% [markdown]
# В европейском регионе популярны игры жанра: Action, Shooter, Sports, Role-Playing, Racing. В данном регионе наиболее популярны жанры, не требующие много времени на игровой процесс (игры жанров Action, Shooter и Sports не требуют знания механик и понятны даже при поверхностном ознакомлении). Первые три места топа занимают жанры, пользующиеся спросом во всем мире.

# %%
na_genre_sales=(sorted_games.pivot_table(index = 'genre', 
                                        values = 'na_sales', aggfunc = 'sum')
                .sort_values(by='na_sales', ascending = False).head())
na_genre_sales
# Out:
#               na_sales
# genre
# Action          177.00
# Shooter         144.77
# Sports           81.38
# Role-Playing     60.65
# Misc             38.13

# %% [markdown]
# В регионе Северной Америки популярны игры жанра: Action, Shooter, Sports, Role-Playing, Misc. Ситуация похоже на европейский регион, что говорит о схожести вкусов, предпочтений к гейм-плею и образу мышлений пользователей.

# %%
jp_genre_sales=(sorted_games.pivot_table(index = 'genre', 
                                        values = 'jp_sales', aggfunc = 'sum')
                .sort_values(by='jp_sales', ascending = False).head())
jp_genre_sales
# Out:
#               jp_sales
# genre
# Role-Playing     59.12
# Action           49.18
# Misc             12.45
# Simulation       10.35
# Shooter           9.23

# %% [markdown]
# В Японсокм регионе популярны игры жанра: Role-Playing, Action, Misc, Shooter, Platform. Жанры, представленные в топе по японскому региону отличаются от данных по двум предыдущим регионам. На первом месте здесь  стоят ролевые игры, отличающиеся в основном множеством механик, разветвленным сюжетом и разнообразными способами прохождения.

# %%
region_genres = eu_genre_sales.join([na_genre_sales, jp_genre_sales], how= 'outer')
region_genres
# Out:
#               eu_sales  na_sales  jp_sales
# genre
# Action          158.43    177.00     49.18
# Shooter         113.47    144.77      9.23
# Sports           68.84     81.38       NaN
# Role-Playing     46.76     60.65     59.12
# Racing           27.29       NaN       NaN
# Misc               NaN     38.13     12.45
# Simulation         NaN       NaN     10.35

# %%
region_genres.plot(kind='bar', figsize = (15,5), width=0.5, grid=True);

# %% [markdown]
# Спрос на жанры в Американском и Европейском регионах похож, кроме того, два этих региона формируют большую часть рынка. Японский регион составляет меньшую долю рынка, кроме того предпочтения по жанрам отличаются от общемирового. Пользователи из Европы и Америки предпочитают игры, не требующие большого внимания в плане механик, с упорм на активный гейм-плэй. В свою очередь японцы отдают предпочтения ролевым играм, что интересно, так основной спрос у них на портативные консоли.

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
sorted_games['rating'] = sorted_games['rating'].fillna('No rating')
sorted_games
# Out:
#                             name platform  year_of_release       genre  \
# 0             Grand Theft Auto V      PS3             2013      Action
# 1     Call of Duty: Black Ops II      PS3             2012     Shooter
# 2           Call of Duty: Ghosts      PS3             2013     Shooter
# 3                 FIFA Soccer 13      PS3             2012      Action
# 4                        FIFA 14      PS3             2013      Sports
# ...                          ...      ...              ...         ...
# 2676       The Longest 5 Minutes      PSV             2016      Action
# 2677            Strawberry Nauts      PSV             2016   Adventure
# 2678            Aiyoku no Eustia      PSV             2014        Misc
# 2679     Haitaka no Psychedelica      PSV             2016   Adventure
# 2680         Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# ...

# %%
eu_rating_sales=(sorted_games.pivot_table(index = 'rating', 
                                        values = 'eu_sales', aggfunc = 'sum')
                 .sort_values(by='eu_sales', ascending = False).head())
eu_rating_sales
# Out:
#            eu_sales
# rating
# M            193.96
# E            111.79
# No rating     89.32
# E10+          54.84
# T             52.96

# %%
na_rating_sales=(sorted_games.pivot_table(index = 'rating', 
                                        values = 'na_sales', aggfunc = 'sum')
                 .sort_values(by='na_sales', ascending = False).head())
na_rating_sales
# Out:
#            na_sales
# rating
# M            231.57
# E            113.44
# No rating    100.13
# E10+          75.09
# T             66.02

# %%
jp_rating_sales=(sorted_games.pivot_table(index = 'rating', 
                                        values = 'jp_sales', aggfunc = 'sum')
                 .sort_values(by='jp_sales', ascending = False).head())
jp_rating_sales
# Out:
#            jp_sales
# rating
# No rating     95.62
# E             27.62
# T             25.76
# M             21.20
# E10+           8.19

# %% [markdown]
# Рейтинг ESRB влияет на продажи врегионах. В Европейском и Американском сегменте в зависимости от установленного рейтинга распределены схоже, основное предпочтение отдается играм с рейтингом M - «Mature» — «От 17 лет» (реализм, кровь, насилие, нецензурная лексика). Однако в Японском регионе основной спрос смещен в пользу игр с широким возрастным порогом.

# %% [markdown]
# После замены NaN значений на No rating, в Европе и Америке топ 5 рейтингов ESRB практичеки одинаковы. На третьем месте теперь No rating, это скорее всего связано с тем, что данные игры не проходили сертификацию ESRB.
# В Японии No rating - первый по популярности. Скорее всего это связано стем, что у Японии своя система рейтингов, отличная от ESRB, кроме того, основная часть игр, выпускаемых в Японии, редко покидает пределы японского рынка, в связи с чем, нет необходимости проходить сертификацию ESRB.

# %% [markdown]
# ### Общий портрет пользователя каждого региона

# %% [markdown]
# **Портрет пользователя каждого региона**
#
# - Пользователь Европейского региона предпочитает разные платформы, преимущественно Xbox, PS и PC (самые распространенные). Выбирает игры жанра Action, Shooter, Sports с возрастным рейтингом М-Е.
#
# - Пользователь Североамериканского региона в основном предпочитает Xbox. Выбирает игры жанра Action, Shooter, Sports с возрастным рейтингом М-Е.
#
# - Пользователь Японского региона предпочитает портативный гейминг. Выбирает игры жанра Role-Playing, Action, с возрастным рейтингом Е-М и игры с неопределенным ESRB рейтингом. Скорее всего это связано стем, что у Японии своя система рейтингов, отличная от ESRB, кроме того, основная часть игр, выпускаемых в Японии, редко покидает пределы японского рынка, в связи с чем, нет необходимости проходить сертификацию ESRB. В игровых жанрах оформился сегмент J-RPG (японская RPG, характерная мультипликационной рисовкой и низкими возрастными рейтингами), скорее всего именно подобными RPG и представлен спрос на ролевые игры в Японии.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1 (Средние пользовательские рейтинги платформ Xbox One и PC одинаковые)

# %%
all_scores
# Out:
#                             name platform  year_of_release       genre  \
# 0             Grand Theft Auto V      PS3             2013      Action
# 1     Call of Duty: Black Ops II      PS3             2012     Shooter
# 2           Call of Duty: Ghosts      PS3             2013     Shooter
# 3                 FIFA Soccer 13      PS3             2012      Action
# 4                        FIFA 14      PS3             2013      Sports
# ...                          ...      ...              ...         ...
# 2676       The Longest 5 Minutes      PSV             2016      Action
# 2677            Strawberry Nauts      PSV             2016   Adventure
# 2678            Aiyoku no Eustia      PSV             2014        Misc
# 2679     Haitaka no Psychedelica      PSV             2016   Adventure
# 2680         Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# Удалим Nan значения в столбце `user_score`

# %%
all_scores= all_scores.dropna(subset=['user_score']).reset_index(drop=True)

# %%
XOne = all_scores.query('platform == "XOne"')
PC = all_scores.query('platform == "PC"')

# %% [markdown]
# **Выдвинем нулевую гипотезу**

# %% [markdown]
# Проверим равенство двух генеральных совокупностей:
#
# `Нулевая гипотеза H₀:` Средние пользовательские рейтинги платформ Xbox One и PC равны.
#
# `Альтернативная гипотеза H₁:`  Средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %%
from scipy import stats as st

sample_1 = XOne['user_score']
sample_2 = PC['user_score']

alpha = .05 # критический уровень статистической значимости

results = st.ttest_ind(
    sample_1, 
    sample_2,
    equal_var = False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Средние пользовательские рейтинги платформ Xbox One и PC различаются")
else:
    print("Средние пользовательские рейтинги платформ Xbox One и PC равны")
# Out:
# p-значение: 0.5489537965134912
# Средние пользовательские рейтинги платформ Xbox One и PC равны

# %% [markdown]
# ### Гипотеза 1 (Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные)

# %%
Action = all_scores.query('genre == "Action"')
Sports = all_scores.query('genre == "Sports"')

# %% [markdown]
# **Выдвинем нулевую гипотезу**

# %% [markdown]
# Начнем доказательство `от противного` проверим равенство двух генеральных совокупностей:
#
# `Нулевая гипотеза H₀:`  Средние пользовательские рейтинги жанров Action и Sports равны.
#
# `Альтернативная гипотеза H₁:`  Средние пользовательские рейтинги жанров Action и Sports различаются.

# %%
from scipy import stats as st

sample_1 =Action['user_score']
sample_2 = Sports['user_score']

alpha = .05 # критический уровень статистической значимости

results = st.ttest_ind(
    sample_1, 
    sample_2,
    equal_var = False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Средние пользовательские рейтинги жанров Action и Sports различаются")
else:
    print("Средние пользовательские рейтинги жанров Action и Sports равны")
# Out:
# p-значение: 7.312394745169519e-20
# Средние пользовательские рейтинги жанров Action и Sports различаются

# %% [markdown]
# Среднее  значение двух генеральных совокупностей может различаться как в положительную, так и отрицательную сторону, именно поэтому, стоит использовать метод scipy.stats.ttest_ind для проверки двусторонней гипотезы.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Из проведенного анализа можно сделать несколько выводов:
#
# 1. Период жизни игровой платформы в среднем составляет около 8 лет, исключением является ПК, но, поскольку комплектующие на ПК постоянно совершенствуются, для него необходимо проводить отдельное исследование.
# 2. Последняя смена поколений консолей на момент исследования произошла в 2011 году, Поэтому к 2016 году осталось ориентировочно 3-4 года до смены поколения консолей, время эту терию подтвердило, поскольку PS5 и XboxSeriesX вышли в 2020 году.
# 3. Самые популярные платформы на период исследования - PS3, Xbox360 и PS4, XboxOne, платформы ппредыдущего поколения еще не ушли с рынка окончательно, однако постепенно уступают рынок новому поколению, кроме того, если рассматривать в плане  потенциальных инвестиций на ближайшие 3-4 года, наиболее перспективными чявляются именно PS4 и XboxOne, на которые, в отличие от PS3 и Xbox360 будут выходить новые игры.
# 4. Общая тенденция рынка на 2016 год - снижение спроса на игры, это надо учитывать при инвестициях, Ближайший скачок интереса к играм планируется с выходом нового поколения консолей в 2019-2020 году. Это не говорит о том, что вложения до 2019-2020 года принесут убытки, однако и сверхприбылей ожидать не приходится.
# 5. Оценки критиков имеют слабое прямое влияние на продажи игр.
# 6. Оценки пользователей практически не влияют на продажи.
# 7. Самый большой сегмент рынка игр - Европа и Америка, предпочтения по жанрам в этих регионах примерно схожи и смещены в сторону шутеров, экшн-игр и спортивных симуляторов, однако в Америке предпочтение по платформе смещено в сторону, производимого там же Xbox, в то время как в Европе предпочитают PS и в меньшей степени Xbox, не настолько популярный в Америке и Японии. Япония занимает меньшую долю рынка и отличается от Европы и Америки не только предпочтением по платформам (в топе целых 3 портативных консоли, в отличии от 1 для других регионов, что связано с тем, что японцы любят игры, но в связи с общей загруженностью рабочих будней предпочитают играть вне дома, по пкти на работу, в перерыв или по пути домой), так и по жанрам, предпочитая РПГ, требующие гораздо большего погружения и более требовательные к пониманию механик, отличающиеся в большинстве нелинейностью прохождения.
# 8. Рейтинг ESRB влияет на продажи врегионах. В Европейском и Американском сегменте в зависимости от установленного рейтинга распределены схоже, основное предпочтение отдается играм с рейтингом M - «Mature» — «От 17 лет» (реализм, кровь, насилие, нецензурная лексика). На третьем месте No rating, это скорее всего связано с тем, что данные игры не проходили сертификацию ESRB. Однако в Японии No rating - первый по популярности. Скорее всего это связано стем, что у Японии своя система рейтингов, отличная от ESRB, кроме того, основная часть игр, выпускаемых в Японии, редко покидает пределы японского рынка, в связи с чем, нет необходимости проходить сертификацию ESRB.
# 9. Средние пользовательские рейтинги платформ Xbox One и PC одинаковы/
# 10. Средние пользовательские рейтинги жанров Action и Sports разные.
#
#
# На основании вышеперечисленного, можно сделать вывод о том, что для грамотного инвестирования, необходимо учесть, что спрос различается по регионам и зависит от ряда фвкторов : жанр, платформа, возрастной рейтинг (читать контент и игровой опыт предоставляемый игрой).
#
# Для успешного инвестирования прийдется учесть, основной рынок на который выйдет игра (Европа/америка либо Япония). Прибыль можно получить и там и там, однако охватить все три рынка и успешно их освоить получится лишь при особо удачном стечении обстоятельств.
#
# Также придется учесть, на какую платформу, планируется к релизу игра, популярность платформ распределена по регионам неравномерно, а разработка игры на несколько платформ - довольно затратный процесс.
#
# В целом, самыми перспективными регионами являются Европа и Америка, поскольку спрос по жанрам и по рейтингу  схож, предпочтения по платформам различаются, но не сильно, кроме того, они занимают наибольшую часть рынка, поэтому объемами продаж можно будет нивелировать различия в спросе на платформы, ориентироваться лучше на флагманские платформы PS и Xbox.
#
# Альтернативный вариант - нишевый рынок Японии и РПГ на портативную консоль с широким возрастным рейтингом.
